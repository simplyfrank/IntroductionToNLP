# %% [markdown]
# # Stemming Words

# %%
import nltk
from urllib import request

# %% [markdown]
# ### Preparing the Text for Processing

# %%
# Requesting the text
url = 'https://www.gutenberg.org/files/55463/55463-0.txt'
response = request.urlopen(url)
raw = response.read().decode('utf8')

# %%
raw_corpus = raw[raw.find('LUCK ***')+9:raw.find('END OF PROJECT')]

# %%
tokens = nltk.word_tokenize(raw_corpus)

# %%
text = nltk.Text(tokens)

# %% [markdown]
# ### Reducing words to their core form

# %% [markdown]
# #### Using standardized Stemmer Versions

# %%
# Loading the Stemmersb
porter = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()

# %%
# Craeting lemmatized versions of the text with either stemmer
tokens_porter = [porter.stem(w) for w in tokens]
tokens_lanc = [lancaster.stem(w) for w in tokens]

# %% [markdown]
# Investigating the results

# %%
tokens_porter[1500:1510]
# Out:
# ['.', 'they', 'had', 'given', 'him', 'no', 'firm', 'foothold', 'in', 'alight']

# %%
tokens_lanc[1500:1510]
# Out:
# ['.', 'they', 'had', 'giv', 'him', 'no', 'firm', 'foothold', 'in', 'alight']

# %% [markdown]
# #### Lemmatizer

# %%
from nltk.stem import WordNetLemmatizer

# Creating the Lemmatizer
lemma = WordNetLemmatizer()
tokens_lemma = [lemma.lemmatize(w) for w in tokens]

# %%
tokens_lemma[:25]
# Out:
# ['Produced',
#  'by',
#  'Demian',
#  'Katz',
#  ',',
#  'Craig',
#  'Kirkwood',
#  ',',
#  'and',
#  'the',
#  'Online',
#  'Distributed',
#  'Proofreading',
#  'Team',
#  'at',
#  'http',
#  ':',
#  '//www.pgdp.net',
#  '(',
#  'Northern',
#  'Illinois',
#  'University',
#  'Digital',
#  'Library',
#  'at']

# %% [markdown]
# ## Creating Features
#
# Manually creating feature representations on strings to work with in Machine Learning Models

# %%
[(len(token), token, token.istitle()) for token in tokens_lemma]
# Out:
# [(8, 'Produced', True),
#  (2, 'by', False),
#  (6, 'Demian', True),
#  (4, 'Katz', True),
#  (1, ',', False),
#  (5, 'Craig', True),
#  (8, 'Kirkwood', True),
#  (1, ',', False),
#  (3, 'and', False),
#  (3, 'the', False),
#  (6, 'Online', True),
#  (11, 'Distributed', True),
#  (12, 'Proofreading', True),
#  (4, 'Team', True),
#  (2, 'at', False),
#  (4, 'http', False),
#  (1, ':', False),
#  (14, '//www.pgdp.net', False),
#  (1, '(', False),
#  (8, 'Northern', True),
#  (8, 'Illinois', True),
#  (10, 'University', True),
#  (7, 'Digital', True),
#  (7, 'Library', True),
#  (2, 'at', False),
#  (4, 'http', False),
#  (1, ':', False),
#  (22, '//digital.lib.niu.edu/', False),
#  (1, ')', False),
#  (11, 'Transcriber', True),
#  (1, '’', False),
#  (1, 's', False),
#  (5, 'Notes', True),
#  (1, ':', False),
#  (4, 'Text', True),
#  (8, 'enclosed', False),
#  (2, 'by', False),
#  (10, 'underscore', False),
#  (2, 'is', False),
#  (2, 'in', False),
#  (6, 'italic', False),
#  (1, '(', False),
#  (9, '_italics_', False),
#  (1, ')', False),
#  (1, ',', False),
#  (3, 'and', False),
#  (4, 'text', False),
#  (8, 'enclosed', False),
#  (2, 'by', False),
#  (5, 'equal', False),
#  (4, 'sign', False),
#  (2, 'is', False),
#  (2, 'in', False),
#  (4, 'bold', False),
#  (1, '(', False),
#  (6, '=bold=', False),
#  (1, ')', False),
#  (1, '.', False),
#  (10, 'Additional', True),
#  (11, 'Transcriber', True),
#  (1, '’', False),
#  (1, 's', False),
#  (5, 'Notes', True),
#  (3, 'are', False),
#  (2, 'at', False),
#  (3, 'the', False),
#  (3, 'end', False),
#  (1, '.', False),
#  (1, '*', False),
#  (1, '*', False),
#  (1, '*', False),
#  (1, '*', False),
#  (1, '*', False),
#  (3, 'NEW', False),
#  (3, 'TIP', False),
#  (3, 'TOP', False),
#  (6, 'WEEKLY', False),
#  (2, 'An', True),
#  (5, 'Ideal', True),
#  (11, 'Publication', True),
#  (3, 'For', True),
#  (3, 'The', True),
#  (8, 'American', True),
#  (5, 'Youth', True),
#  (7, '_Issued', True),
#  (6, 'Weekly', True),
#  (1, '.', False),
#  (7, 'Entered', True),
#  (1, 'a', False),
#  (12, 'Second-class', False),
#  (6, 'Matter', True),
#  (2, 'at', False),
#  (3, 'the', False),
#  (3, 'New', True),
#  (4, 'York', True),
#  (4, 'Post', True),
#  (6, 'Office', True),
#  (1, ',', False),
#  (9, 'according', False),
#  (2, 'to', False),
#  (2, 'an', False),
#  (3, 'act', False),
#  (2, 'of', False),
#  (8, 'Congress', True),
#  (1, ',', False),
#  (5, 'March', True),
#  (1, '3', False),
#  (1, ',', False),
#  (4, '1879', False),
#  (1, '.', False),
#  (9, 'Published', True),
#  (3, 'by_', False),
#  (6, 'STREET', False),
#  (1, '&', False),
#  (5, 'SMITH', False),
#  (1, ',', False),
#  (6, '_79-89', False),
#  (7, 'Seventh', True),
#  (4, 'Ave.', True),
#  (1, ',', False),
#  (3, 'New', True),
#  (4, 'York', True),
#  (1, '.', False),
#  (9, 'Copyright', True),
#  (1, ',', False),
#  (4, '1914', False),
#  (1, ',', False),
#  (3, 'by_', False),
#  (6, 'STREET', False),
#  (1, '&', False),
#  (5, 'SMITH', False),
#  (1, '.', False),
#  (2, '_O', True),
#  (1, '.', False),
#  (2, 'G.', True),
#  (5, 'Smith', True),
#  (3, 'and', False),
#  (2, 'G.', True),
#  (2, 'C.', True),
#  (5, 'Smith', True),
#  (1, ',', False),
#  (13, 'Proprietors._', True),
#  (5, 'Terms', True),
#  (2, 'to', False),
#  (3, 'NEW', False),
#  (3, 'TIP', False),
#  (3, 'TOP', False),
#  (6, 'WEEKLY', False),
#  (4, 'Mail', True),
#  (11, 'Subscribers', True),
#  (1, '.', False),
#  (1, '(', False),
#  (8, '_Postage', True),
#  (6, 'Free._', True),
#  (1, ')', False),
#  (6, 'Single', True),
#  (6, 'Copies', True),
#  (2, 'or', False),
#  (4, 'Back', True),
#  (7, 'Numbers', True),
#  (1, ',', False),
#  (2, '5c', False),
#  (1, '.', False),
#  (4, 'Each', True),
#  (1, '.', False),
#  (1, '3', False),
#  (5, 'month', False),
#  (3, '65c', False),
#  (1, '.', False),
#  (1, '4', False),
#  (5, 'month', False),
#  (3, '85c', False),
#  (1, '.', False),
#  (1, '6', False),
#  (5, 'month', False),
#  (1, '$', False),
#  (4, '1.25', False),
#  (3, 'One', True),
#  (4, 'year', False),
#  (4, '2.50', False),
#  (1, '2', False),
#  (4, 'copy', False),
#  (3, 'one', False),
#  (4, 'year', False),
#  (4, '4.00', False),
#  (1, '1', False),
#  (4, 'copy', False),
#  (3, 'two', False),
#  (4, 'year', False),
#  (4, '4.00', False),
#  (4, '=How', True),
#  (2, 'to', False),
#  (4, 'Send', True),
#  (6, 'Money=', True),
#  (2, '--', False),
#  (2, 'By', True),
#  (11, 'post-office', False),
#  (2, 'or', False),
#  (7, 'express', False),
#  (5, 'money', False),
#  (5, 'order', False),
#  (1, ',', False),
#  (10, 'registered', False),
#  (6, 'letter', False),
#  (1, ',', False),
#  (4, 'bank', False),
#  (5, 'check', False),
#  (2, 'or', False),
#  (5, 'draft', False),
#  (1, ',', False),
#  (2, 'at', False),
#  (3, 'our', False),
#  (4, 'risk', False),
#  (1, '.', False),
#  (2, 'At', True),
#  (4, 'your', False),
#  (3, 'own', False),
#  (4, 'risk', False),
#  (2, 'if', False),
#  (4, 'sent', False),
#  (2, 'by', False),
#  (8, 'currency', False),
#  (1, ',', False),
#  (4, 'coin', False),
#  (1, ',', False),
#  (2, 'or', False),
#  (7, 'postage', False),
#  (5, 'stamp', False),
#  (2, 'in', False),
#  (8, 'ordinary', False),
#  (6, 'letter', False),
#  (1, '.', False),
#  (10, '=Receipts=', True),
#  (2, '--', False),
#  (7, 'Receipt', True),
#  (2, 'of', False),
#  (4, 'your', False),
#  (10, 'remittance', False),
#  (2, 'is', False),
#  (12, 'acknowledged', False),
#  (2, 'by', False),
#  (6, 'proper', False),
#  (6, 'change', False),
#  (2, 'of', False),
#  (6, 'number', False),
#  (2, 'on', False),
#  (4, 'your', False),
#  (5, 'label', False),
#  (1, '.', False),
#  (2, 'If', True),
#  (3, 'not', False),
#  (7, 'correct', False),
#  (3, 'you', False),
#  (4, 'have', False),
#  (3, 'not', False),
#  (4, 'been', False),
#  (8, 'properly', False),
#  (8, 'credited', False),
#  (1, ',', False),
#  (3, 'and', False),
#  (6, 'should', False),
#  (3, 'let', False),
#  (1, 'u', False),
#  (4, 'know', False),
#  (2, 'at', False),
#  (4, 'once', False),
#  (1, '.', False),
#  (2, 'No', True),
#  (1, '.', False),
#  (2, '77', False),
#  (1, '.', False),
#  (3, 'NEW', False),
#  (4, 'YORK', False),
#  (1, ',', False),
#  (7, 'January', True),
#  (2, '17', False),
#  (1, ',', False),
#  (4, '1914', False),
#  (1, '.', False),
#  (5, 'Price', True),
#  (4, 'Five', True),
#  (5, 'Cents', True),
#  (1, '.', False),
#  (4, 'OWEN', False),
#  (6, 'CLANCY', False),
#  (1, '’', False),
#  (1, 'S', True),
#  (3, 'RUN', False),
#  (2, 'OF', False),
#  (4, 'LUCK', False),
#  (1, ';', False),
#  (2, 'Or', True),
#  (1, ',', False),
#  (3, 'THE', False),
#  (5, 'MOTOR', False),
#  (6, 'WIZARD', False),
#  (2, 'IN', False),
#  (3, 'THE', False),
#  (6, 'GARAGE', False),
#  (1, '.', False),
#  (2, 'By', True),
#  (4, 'BURT', False),
#  (2, 'L.', True),
#  (8, 'STANDISH', False),
#  (1, '.', False),
#  (7, 'CHAPTER', False),
#  (1, 'I', True),
#  (1, '.', False),
#  (4, 'OVER', False),
#  (3, 'THE', False),
#  (3, 'RIM', False),
#  (4, 'ROCK', False),
#  (1, '.', False),
#  (4, 'Honk', True),
#  (1, ',', False),
#  (7, 'h-o-n-k', False),
#  (1, '!', False),
#  (1, '“', False),
#  (4, 'Look', True),
#  (3, 'out', False),
#  (5, 'there', False),
#  (1, '!', False),
#  (4, 'Jump', True),
#  (2, '--', False),
#  (4, 'jump', False),
#  (1, '!', False),
#  (1, '”', False),
#  (4, 'High', True),
#  (5, 'above', False),
#  (5, 'these', False),
#  (5, 'sound', False),
#  (5, 'there', False),
#  (5, 'broke', False),
#  (1, 'a', False),
#  (8, 'startled', False),
#  (4, 'yell', False),
#  (1, '.', False),
#  (4, 'Owen', True),
#  (6, 'Clancy', True),
#  (1, ',', False),
#  (3, 'who', False),
#  (2, 'wa', False),
#  (8, 'tramping', False),
#  (5, 'along', False),
#  (3, 'the', False),
#  (4, 'road', False),
#  (4, 'with', False),
#  (3, 'his', False),
#  (4, 'coat', False),
#  (4, 'over', False),
#  (3, 'his', False),
#  (3, 'arm', False),
#  (1, ',', False),
#  (3, 'not', False),
#  (4, 'only', False),
#  (5, 'heard', False),
#  (3, 'the', False),
#  (4, 'yell', False),
#  (1, ',', False),
#  (3, 'but', False),
#  (6, 'caught', False),
#  (3, 'one', False),
#  (6, 'tragic', False),
#  (7, 'glimpse', False),
#  (2, 'of', False),
#  (1, 'a', False),
#  (6, 'figure', False),
#  (7, 'soaring', False),
#  (7, 'through', False),
#  (3, 'the', False),
#  (5, 'cloud', False),
#  (2, 'of', False),
#  (4, 'dust', False),
#  (1, ',', False),
#  (8, 'dropping', False),
#  (2, 'in', False),
#  (1, 'a', False),
#  (6, 'sprawl', False),
#  (2, 'on', False),
#  (3, 'the', False),
#  (4, 'rock', False),
#  (1, ',', False),
#  (3, 'and', False),
#  (4, 'then', False),
#  (7, 'rolling', False),
#  (4, 'over', False),
#  (3, 'the', False),
#  (4, 'edge', False),
#  (2, 'of', False),
#  (3, 'the', False),
#  (5, 'cliff', False),
#  (1, '.', False),
#  (1, '“', False),
#  (5, 'Great', True),
#  (7, 'jumping', False),
#  (4, 'horn', False),
#  (4, 'toad', False),
#  (1, '!', False),
#  (1, '”', False),
#  (6, 'gulped', False),
#  (3, 'the', False),
#  (10, 'red-headed', False),
#  (4, 'chap', False),
#  (1, ',', False),
#  (6, 'coming', False),
#  (2, 'to', False),
#  (2, 'an', False),
#  (9, 'astounded', False),
#  (4, 'halt', False),
#  (1, ',', False),
#  (5, 'every', False),
#  (5, 'nerve', False),
#  (2, 'in', False),
#  (1, 'a', False),
#  (6, 'quiver', False),
#  (1, '.', False),
#  (1, '“', False),
#  (5, 'Right', True),
#  (4, 'over', False),
#  (3, 'the', False),
#  (9, 'precipice', False),
#  (1, ',', False),
#  (2, 'by', False),
#  (7, 'thunder', False),
#  (1, '!', False),
#  (4, 'That', True),
#  (6, 'fellow', False),
#  (1, '’', False),
#  (1, 's', False),
#  (4, 'done', False),
#  (3, 'for', False),
#  (1, ',', False),
#  (3, 'and', False),
#  (2, 'no', False),
#  (7, 'mistake', False),
#  (1, '.', False),
#  (3, 'The', True),
#  (3, 'man', False),
#  (6, 'behind', False),
#  (4, 'that', False),
#  (8, 'steering', False),
#  (5, 'wheel', False),
#  (5, 'ought', False),
#  (2, 'to', False),
#  (2, 'be', False),
#  (7, 'pinched', False),
#  (1, '!', False),
#  (2, 'He', True),
#  (4, 'didn', False),
#  (1, '’', False),
#  (1, 't', False),
#  (4, 'give', False),
#  (3, 'the', False),
#  (6, 'fellow', False),
#  (2, 'in', False),
#  (3, 'the', False),
#  (5, 'trail', False),
#  (3, 'any', False),
#  (6, 'chance', False),
#  (2, 'at', False),
#  (3, 'all', False),
#  (2, '--', False),
#  (4, 'just', False),
#  (3, 'ran', False),
#  (3, 'him', False),
#  (4, 'down', False),
#  (3, 'and', False),
#  (4, 'made', False),
#  (3, 'him', False),
#  (4, 'jump', False),
#  (4, 'over', False),
#  (3, 'the', False),
#  (4, 'edge', False),
#  (2, 'of', False),
#  (3, 'the', False),
#  (5, 'cliff', False),
#  (1, '.', False),
#  (3, 'Now', True),
#  (3, 'the', False),
#  (6, 'driver', False),
#  (2, 'of', False),
#  (4, 'that', False),
#  (3, 'car', False),
#  (4, 'hasn', False),
#  (1, '’', False),
#  (1, 't', False),
#  (3, 'the', False),
#  (6, 'common', False),
#  (7, 'decency', False),
#  (2, 'to', False),
#  (4, 'come', False),
#  (4, 'back', False),
#  (3, 'and', False),
#  (3, 'see', False),
#  (3, 'how', False),
#  (4, 'much', False),
#  (4, 'harm', False),
#  (2, 'ha', False),
#  (4, 'been', False),
#  (4, 'done', False),
#  (1, '!', False),
#  (1, '”', False),
#  (3, 'The', True),
#  (5, 'scene', False),
#  (2, 'of', False),
#  (4, 'this', False),
#  (8, 'reckless', False),
#  (10, 'automobile', False),
#  (7, 'driving', False),
#  (2, 'wa', False),
#  (1, 'a', False),
#  (5, 'trail', False),
#  (7, 'leading', False),
#  (6, 'toward', False),
#  (3, 'the', False),
#  (4, 'city', False),
#  (2, 'of', False),
#  (7, 'Phoenix', True),
#  (1, ',', False),
#  (7, 'Arizona', True),
#  (1, '.', False),
#  (2, 'It', True),
#  (2, 'wa', False),
#  (3, 'one', False),
#  (2, 'of', False),
#  (5, 'those', False),
#  (19, 'mountain-and-desert', False),
#  (5, 'trail', False),
#  (5, 'which', False),
#  (4, 'lead', False),
#  (3, 'for', False),
#  (4, 'mile', False),
#  (4, 'over', False),
#  (7, 'thirsty', False),
#  (1, ',', False),
#  (12, 'sun-scorched', False),
#  (5, 'plain', False),
#  (1, ',', False),
#  (3, 'and', False),
#  (12, 'occasionally', False),
#  (5, 'climb', False),
#  (2, 'to', False),
#  (5, 'dizzy', False),
#  (6, 'height', False),
#  (2, 'by', False),
#  (6, 'narrow', False),
#  (1, ',', False),
#  (12, 'hair-raising', False),
#  (6, 'spiral', False),
#  (7, 'clipped', False),
#  (4, 'from', False),
#  (3, 'the', False),
#  (12, 'mountainside', False),
#  (1, '.', False),
#  (6, 'Clancy', True),
#  (1, ',', False),
#  (2, 'at', False),
#  (3, 'the', False),
#  (4, 'high', False),
#  (5, 'point', False),
#  (2, 'of', False),
#  (3, 'the', False),
#  (5, 'trail', False),
#  (1, ',', False),
#  (3, 'had', False),
#  (4, 'been', False),
#  (8, 'crossing', False),
#  (1, 'a', False),
#  (6, 'rugged', False),
#  (1, ',', False),
#  (15, 'bowlder-covered', False),
#  (6, 'uplift', False),
#  (1, '.', False),
#  (2, 'At', True),
#  (3, 'his', False),
#  (4, 'left', False),
#  (2, 'wa', False),
#  (1, 'a', False),
#  (5, 'blank', False),
#  (4, 'wall', False),
#  (1, ',', False),
#  (1, 'a', False),
#  (7, 'hundred', False),
#  (4, 'foot', False),
#  (4, 'high', False),
#  (1, ';', False),
#  (5, 'under', False),
#  (3, 'his', False),
#  (4, 'foot', False),
#  (2, 'wa', False),
#  (1, 'a', False),
#  (5, 'shelf', False),
#  (1, ',', False),
#  (6, 'barely', False),
#  (4, 'wide', False),
#  (6, 'enough', False),
#  (3, 'for', False),
#  (3, 'the', False),
#  (4, 'road', False),
#  (1, ';', False),
#  (3, 'and', False),
#  (1, ',', False),
#  (2, 'on', False),
#  (3, 'his', False),
#  (5, 'right', False),
#  (1, ',', False),
#  (2, 'wa', False),
#  (1, 'a', False),
#  (9, 'precipice', False),
#  (1, '.', False),
#  (5, 'Those', True),
#  (6, 'height', False),
#  (10, 'overlooked', False),
#  (1, 'a', False),
#  (5, 'dusty', False),
#  (7, 'stretch', False),
#  (2, 'of', False),
#  (4, 'flat', False),
#  (6, 'desert', False),
#  (1, ',', False),
#  (2, 'at', False),
#  (5, 'whose', False),
#  (7, 'farther', False),
#  (4, 'edge', False),
#  (5, 'could', False),
#  (2, 'be', False),
#  (4, 'seen', False),
#  (3, 'the', False),
#  (7, 'rooftop', False),
#  (3, 'and', False),
#  (5, 'spire', False),
#  (2, 'of', False),
#  (7, 'Phoenix', True),
#  (7, 'peeping', False),
#  (3, 'out', False),
#  (2, 'of', False),
#  (3, 'the', False),
#  (5, 'green', False),
#  (7, 'treetop', False),
#  (1, '.', False),
#  (3, 'The', True),
#  (4, 'city', False),
#  (1, ',', False),
#  (4, 'from', False),
#  (4, 'that', False),
#  (8, 'distance', False),
#  (1, ',', False),
#  (9, 'presented', False),
#  (1, 'a', False),
#  (4, 'most', False),
#  (10, 'enchanting', False),
#  (4, 'view', False),
#  (1, ',', False),
#  (3, 'and', False),
#  (6, 'Clancy', True),
#  (3, 'had', False),
#  (6, 'paused', False),
#  (2, 'to', False),
#  (4, 'look', False),
#  (3, 'and', False),
#  (2, 'to', False),
#  (6, 'admire', False),
#  (1, '.', False),
#  (1, '“', False),
#  (6, 'Wonder', True),
#  (4, 'what', False),
#  (4, 'sort', False),
#  (2, 'of', False),
#  (4, 'luck', False),
#  (1, 'I', True),
#  (1, '’', False),
#  (1, 'm', False),
#  (5, 'going', False),
#  (2, 'to', False),
#  (4, 'have', False),
#  (2, 'in', False),
#  (4, 'that', False),
#  (4, 'town', False),
#  (1, '?', False),
#  (1, '”', False),
#  (2, 'he', False),
#  (3, 'had', False),
#  (5, 'asked', False),
#  (7, 'himself', False),
#  (1, '.', False),
#  (1, '“', False),
#  (1, 'I', True),
#  (1, '’', False),
#  (2, 've', False),
#  (3, 'got', False),
#  (1, 'a', False),
#  (6, 'notion', False),
#  (2, 'it', False),
#  (2, 'is', False),
#  (5, 'going', False),
#  (2, 'to', False),
#  (4, 'make', False),
#  (2, 'or', False),
#  (5, 'break', False),
#  (2, 'me', False),
#  (1, '.', False),
#  (4, 'Well', True),
#  (1, ',', False),
#  (1, '”', False),
#  (3, 'and', False),
#  (2, 'he', False),
#  (7, 'frowned', False),
#  (10, 'resolutely', False),
#  (1, ',', False),
#  (1, '“', False),
#  (2, 'if', False),
#  (2, 'it', False),
#  (5, 'break', False),
#  (2, 'me', False),
#  (1, ',', False),
#  (1, 'I', True),
#  (1, '’', False),
#  (2, 'll', False),
#  (4, 'make', False),
#  (4, 'good', False),
#  (9, 'somewhere', False),
#  (4, 'else', False),
#  (1, '.', False),
#  (1, 'I', True),
#  (1, '’', False),
#  (1, 'm', False),
#  (3, 'the', False),
#  (4, 'head', False),
#  (2, 'of', False),
#  (3, 'the', False),
#  (6, 'family', False),
#  (3, 'now', False),
#  (1, ',', False),
#  (3, 'and', False),
#  (2, 'it', False),
#  (2, 'is', False),
#  (2, 'up', False),
#  (2, 'to', False),
#  (2, 'me', False),
#  (2, 'to', False),
#  (4, 'show', False),
#  (3, 'the', False),
#  (4, 'folk', False),
#  (4, 'back', False),
#  (4, 'East', True),
#  (4, 'just', False),
#  (4, 'what', False),
#  (4, 'sort', False),
#  (2, 'of', False),
#  (1, 'a', False),
#  (6, 'little', False),
#  (1, ',', False),
#  (10, 'red-headed', False),
#  (11, 'breadwinner', False),
#  (1, 'I', True),
#  (2, 'am', False),
#  (1, '.', False),
#  (1, 'I', True),
#  (1, '’', False),
#  (2, 'll', False),
#  (2, '--', False),
#  (2, '--', False),
#  (1, '”', False),
#  (2, 'He', True),
#  (5, 'broke', False),
#  (3, 'off', False),
#  (3, 'his', False),
#  (10, 'reflection', False),
#  (8, 'abruptly', False),
#  (1, '.', False),
#  (4, 'From', True),
#  (6, 'behind', False),
#  (3, 'him', False),
#  (1, ',', False),
#  (3, 'and', False),
#  (10, 'altogether', False),
#  (3, 'too', False),
#  (5, 'close', False),
#  (3, 'for', False),
#  (7, 'comfort', False),
#  (1, ',', False),
#  (4, 'came', False),
#  (3, 'the', False),
#  (4, 'toot', False),
#  (2, 'of', False),
#  (1, 'a', False),
#  (5, 'motor', False),
#  (4, 'horn', False),
#  (1, '.', False),
#  (12, 'Accompanying', True),
#  (3, 'the', False),
#  (5, 'sound', False),
#  (5, 'there', False),
#  (5, 'burst', False),
#  (5, 'forth', False),
#  (3, 'the', False),
#  (4, 'loud', False),
#  (3, 'run', False),
#  (2, 'of', False),
#  (1, 'a', False),
#  (5, 'motor', False),
#  (1, '.', False),
#  (6, 'Clancy', True),
#  (1, ',', False),
#  (6, 'always', False),
#  (5, 'quick', False),
#  (2, 'to', False),
#  (3, 'act', False),
#  (2, 'in', False),
#  (2, 'an', False),
#  (9, 'emergency', False),
#  (1, ',', False),
#  (4, 'gave', False),
#  (3, 'one', False),
#  (4, 'leap', False),
#  (3, 'for', False),
#  (3, 'the', False),
#  (5, 'blank', False),
#  (4, 'wall', False),
#  (2, 'at', False),
#  (3, 'the', False),
#  (9, 'trailside', False),
#  (1, ',', False),
#  (3, 'and', False),
#  (9, 'flattened', False),
#  (7, 'against', False),
#  (2, 'it', False),
#  (1, '.', False),
#  (3, 'Not', True),
#  (2, 'an', False),
#  (7, 'instant', False),
#  (3, 'too', False),
#  (4, 'soon', False),
#  (3, 'did', False),
#  (2, 'he', False),
#  (10, 'accomplish', False),
#  (4, 'this', False),
#  (1, ',', False),
#  (3, 'for', False),
#  (1, ',', False),
#  (3, 'ere', False),
#  (2, 'he', False),
#  (5, 'could', False),
#  (4, 'draw', False),
#  (1, 'a', False),
#  (4, 'full', False),
#  (6, 'breath', False),
#  (1, ',', False),
#  (1, 'a', False),
#  (3, 'big', False),
#  (1, ',', False),
#  (5, 'black', False),
#  (3, 'car', False),
#  (7, 'lurched', False),
#  (4, 'past', False),
#  (1, ',', False),
#  (3, 'the', False),
#  (3, 'mud', False),
#  (5, 'guard', False),
#  (6, 'almost', False),
#  (8, 'brushing', False),
#  (3, 'his', False),
#  (4, 'knee', False),
#  (1, '.', False),
#  (2, 'It', True),
#  (2, 'wa', False),
#  (1, 'a', False),
#  (12, 'six-cylinder', False),
#  (7, 'machine', False),
#  (1, ',', False),
#  (5, 'built', False),
#  (2, 'to', False),
#  (5, 'carry', False),
#  (5, 'seven', False),
#  (9, 'passenger', False),
#  (1, ',', False),
#  (3, 'but', False),
#  (5, 'there', False),
#  (2, 'wa', False),
#  (4, 'only', False),
#  (3, 'the', False),
#  (6, 'driver', False),
#  (6, 'aboard', False),
#  (1, '.', False),
#  (7, 'Lightly', True),
#  (9, 'ballasted', False),
#  (1, ',', False),
#  (3, 'the', False),
#  (4, 'huge', False),
#  (7, 'machine', False),
#  (6, 'jumped', False),
#  (3, 'and', False),
#  (6, 'swayed', False),
#  (2, 'on', False),
#  (4, 'that', False),
#  (9, 'dangerous', False),
#  (4, 'path', False),
#  (2, 'in', False),
#  (1, 'a', False),
#  (6, 'manner', False),
#  (2, 'to', False),
#  (4, 'make', False),
#  (3, 'the', False),
#  (5, 'heart', False),
#  (4, 'jump', False),
#  (1, '.', False),
#  (3, 'But', True),
#  (5, 'there', False),
#  (2, 'wa', False),
#  (9, 'something', False),
#  (4, 'else', False),
#  (4, 'that', False),
#  (4, 'made', False),
#  (6, 'Clancy', True),
#  (1, '’', False),
#  (1, 's', False),
#  (5, 'heart', False),
#  (4, 'jump', False),
#  (1, '.', False),
#  (2, 'He', True),
#  (8, 'suddenly', False),
#  (6, 'became', False),
#  (5, 'aware', False),
#  (2, 'of', False),
#  (7, 'another', False),
#  (10, 'pedestrian', False),
#  (2, 'in', False),
#  (3, 'the', False),
#  (4, 'road', False),
#  (1, ',', False),
#  (1, 'a', False),
#  (6, 'fellow', False),
#  (2, 'he', False),
#  (3, 'had', False),
#  (3, 'not', False),
#  (4, 'seen', False),
#  (6, 'before', False),
#  (1, '.', False),
#  (2, 'In', True),
#  (3, 'the', False),
#  (7, 'instant', False),
#  (2, 'of', False),
#  (4, 'time', False),
#  (7, 'allowed', False),
#  (3, 'him', False),
#  (3, 'for', False),
#  (6, 'making', False),
#  (11, 'observation', False),
#  (1, ',', False),
#  (6, 'Clancy', True),
#  (3, 'saw', False),
#  (4, 'only', False),
#  (4, 'that', False),
#  (3, 'the', False),
#  (5, 'other', False),
#  (4, 'foot', False),
#  (8, 'traveler', False),
#  (2, 'wa', False),
#  (1, 'a', False),
#  (8, 'youngish', False),
#  (4, 'chap', False),
#  (1, ',', False),
#  (3, 'and', False),
#  (4, 'that', False),
#  (2, 'he', False),
#  (2, 'wa', False),
#  (9, 'loitering', False),
#  (5, 'along', False),
#  (11, 'unconscious', False),
#  (2, 'of', False),
#  (3, 'the', False),
#  (8, 'speeding', False),
#  (3, 'car', False),
#  (6, 'behind', False),
#  (3, 'him', False),
#  (1, '.', False),
#  (3, 'The', True),
#  (6, 'driver', False),
#  (2, 'of', False),
#  (3, 'the', False),
#  (7, 'machine', False),
#  (3, 'did', False),
#  (3, 'not', False),
#  (7, 'slacken', False),
#  (4, 'gait', False),
#  (2, 'in', False),
#  (3, 'the', False),
#  (5, 'least', False),
#  (1, ',', False),
#  (3, 'but', False),
#  (9, 'contented', False),
#  (7, 'himself', False),
#  (4, 'with', False),
#  (6, 'merely', False),
#  (8, 'sounding', False),
#  (3, 'the', False),
#  (4, 'horn', False),
#  (1, '.', False),
#  (6, 'Wildly', True),
#  (6, 'Clancy', True),
#  ...]

# %%
# Counting the longest word in a sequence
maxlen = max(len(token) for token in text)
[word for word in text if len(word) == maxlen]

# %%
# Out:
# ['//www.gutenberg.org/5/5/4/6/55463/']

# %%
# Creating bigrams from text
word_token_sents = [nltk.word_tokenize(sent) for sent in nltk.sent_tokenize(raw_corpus)]
n = 3
trigrams = [[sent[i:i+n] for i in range(len(sent)-n+1)] for sent in word_token_sents]

# %%
len(trigrams)
# Out:
# 2370
