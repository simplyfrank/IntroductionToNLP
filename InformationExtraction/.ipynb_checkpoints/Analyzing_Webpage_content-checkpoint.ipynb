# %% [markdown]
# # Analyzing Webpage Content with NLP
#
#
# *Author*: Frank Fichtenmueller <br>
# *Date*: 05/09/2017<br>
# <hr>
# *Goal*: To describe a simple Processing Pipeline to be applied to Webpage Content to extract relevant pieces of information

# %%
# Imports
from urllib import request
import nltk
from bs4 import BeautifulSoup

# %% [markdown]
# ### Accessing the text from the Page

# %%
def get_text(url, tokenize="words", urlencode='lxml', decoder='utf8'):
    html = request.urlopen(url).read().decode(decoder)
    raw = BeautifulSoup(html, urlencode).get_text()
    
    # Apply tokenization to the raw text
    switch = {
        'words': nltk.word_tokenize(raw),
        'sentences': nltk.sent_tokenize(raw),
        'word_sentences': [[word for word in nltk.word_tokenize(sent)] for sent in nltk.sent_tokenize(raw)],
        'raw': raw
    }
    
    return switch[tokenize]

# %%
get_text('http://mostly.ai/summit/#undefined', 'word_sentences')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-121-ab7088733c17> in <module>()
# ----> 1 get_text('http://mostly.ai/summit/#undefined', 'word_sentences')
#
# <ipython-input-120-11ce2c767ac6> in get_text(url, tokenize, urlencode, decoder)
#       1 def get_text(url, tokenize="words", urlencode='lxml', decoder='utf8'):
#       2     html = request.urlopen(url).read().decode(decoder)
# ----> 3     raw = nltk.clean_html(BeautifulSoup(html, urlencode).get_text())
#       4
#       5     # Apply tokenization to the raw text
#
# ~\Anaconda3\lib\site-packages\nltk\util.py in clean_html(html)
#     354
#     355 def clean_html(html):
# --> 356     raise NotImplementedError ("To remove HTML markup, use BeautifulSoup's get_text() function")
#     357
#     358 def clean_url(url):
#
# NotImplementedError: To remove HTML markup, use BeautifulSoup's get_text() function

# %% [markdown]
# ### Creating a Frequency based count on the Words

# %%
def freq_words(text, lower=True, n=10):
    """
    Calculate the most frequent words in a given text and return them as a list.
    
    Given a string representation of a text, return the n most common / uncommon 
    words in the text.
    """
    # Create the Frequency Distribution
    if lower:
        freqdist = nltk.FreqDist(word.lower() for word in text)
    else:
        freqdist = nltk.FreqDist(word for word in text)
    
    # Return the n most common words
    return [word for (word, _) in freqdist.most_common(n)]

# %%
# Getting the text
text = get_text('http://mostly.ai/summit/#undefined', 'words')

# Extracting the most frequent words
freq_words(text, lower=False, n=15)
# Out:
# ["''",
#  ',',
#  '``',
#  ':',
#  '.',
#  'and',
#  'the',
#  'of',
#  ')',
#  '(',
#  'in',
#  'to',
#  '{',
#  '}',
#  'Learning']

# %% [markdown]
# ### Cleaning the Text

# %%
def clean_text(text, language='english', stopwords=True, punctuation=True):
    """
    Remove stopwords, punctuation and html code from the text
    """
    # Clean Punctuation
    if punctuation:
        # Defining the regex
        regex = re.compile('[%s]' % re.escape(string.punctuation))

        filtered_text = []

        for sent in text:
            new_sent = []
            for token in sent:
                new_token = regex.sub(u'', token)
                if not new_token == u'':
                    new_sent.append(new_token)
            
            filtered_text.append(new_sent)
            text = filtered_text
            
    # Remove Stopwords from Text 
    if stopwords:
        from nltk.corpus import stopwords
        filtered_text = [word for word in text if word not in stopwords.words(language)]
    
    return filtered_text

# %%
clean_text(text, language='english', stopwords=True, punctuation=True)
# Out:
# [['AI',
#   'Summit',
#   'Vienna',
#   'AI',
#   'Advances',
#   'Insights',
#   'on',
#   'the',
#   'latest',
#   'advances',
#   'in',
#   'the',
#   'field',
#   'and',
#   'where',
#   'we',
#   'are',
#   'heading'],
#  ['Deep',
#   'Learning',
#   'Dive',
#   'into',
#   'the',
#   'powerful',
#   'model',
#   'classes',
#   'that',
#   'are',
#   'behind',
#   'the',
#   'current',
#   'AI',
#   'revival'],
#  ['ML',
#   'Use',
#   'Cases',
#   'Realworld',
#   'applications',
#   'of',
#   'machine',
#   'learning',
#   'shared',
#   'by',
#   'seasoned',
#   'practitioners'],
#  ['Networking',
#   'Informal',
#   'gettogether',
#   'of',
#   'AI',
#   'enthusiasts',
#   'at',
#   'one',
#   'of',
#   'Europe',
#   's',
#   'most',
#   'modern',
#   'campuses'],
#  ['Learn',
#   'from',
#   'Leading',
#   'AI',
#   'Experts',
#   'Selflearning',
#   'machines',
#   'are',
#   'outperforming',
#   'humans',
#   'in',
#   'decision',
#   'making',
#   'at',
#   'an',
#   'ever',
#   'increasing',
#   'pace'],
#  ['These',
#   'ongoing',
#   'advancements',
#   'are',
#   'fueled',
#   'by',
#   '1',
#   'more',
#   'efficient',
#   'algorithms',
#   '2',
#   'faster',
#   'processing',
#   'power',
#   'and',
#   '3',
#   'an',
#   'expontential',
#   'growth',
#   'in',
#   'data'],
#  ['By',
#   'bringing',
#   'together',
#   'leading',
#   'AI',
#   'researchers',
#   'and',
#   'practitioners',
#   'here',
#   'in',
#   'Vienna',
#   'we',
#   'will',
#   'have',
#   'the',
#   'unique',
#   'opportunity',
#   'to',
#   'go',
#   'beyond',
#   'the',
#   'hype',
#   'and',
#   'gain',
#   'a',
#   'practical',
#   'understanding',
#   'of',
#   'artificial',
#   'intelligence',
#   'its',
#   'potential',
#   'as',
#   'well',
#   'as',
#   'its',
#   'underlying',
#   'algorithms'],
#  ['Our',
#   'Promise',
#   'a',
#   'nonprofit',
#   'contentrich',
#   'AI',
#   'Summit',
#   'tailored',
#   'to',
#   'a',
#   'forwardthinking',
#   'and',
#   'techsavvy',
#   'audience',
#   'Program',
#   'Note',
#   'We',
#   'will',
#   'use',
#   'slidocom',
#   'to',
#   'manage',
#   'Q',
#   'A',
#   'session',
#   'after',
#   'the',
#   'talks'],
#  ['Feel',
#   'free',
#   'to',
#   'post',
#   'and',
#   'vote',
#   'questions',
#   'at',
#   'https',
#   'appslidoeventfzxgjgkkask'],
#  ['And',
#   'in',
#   'case',
#   'you',
#   'feel',
#   'like',
#   'sharing',
#   'online',
#   'the',
#   'official',
#   'hashtag',
#   'of',
#   'the',
#   'event',
#   'is',
#   'AISV17'],
#  ['September',
#   '04',
#   'AI',
#   'Summit',
#   'Vienna',
#   '1530',
#   '1600',
#   'Checkin',
#   'Collect',
#   'your',
#   'entrance',
#   'pass'],
#  ['1600', '1620', 'Welcome', 'You', 've', 'made', 'it'],
#  ['1620',
#   '1700',
#   'Machine',
#   'Learning',
#   'with',
#   'Google',
#   'Cloud',
#   'Dave',
#   'Elliott',
#   'Google',
#   'Global',
#   'Product',
#   'Lead',
#   '1700',
#   '1740',
#   'Neural',
#   'Networks',
#   'for',
#   'Natural',
#   'Language',
#   'Processing',
#   'Tomáš',
#   'Mikolov',
#   'Facebook',
#   'AI',
#   'Research',
#   'Scientist',
#   '1740',
#   '1820',
#   'Break',
#   'Snacks',
#   'drinks'],
#  ['1820',
#   '1900',
#   'Deep',
#   'Learning',
#   'is',
#   'Evolving',
#   'into',
#   'the',
#   'Key',
#   'Technology',
#   'of',
#   'Artificial',
#   'Intelligence',
#   'Sepp',
#   'Hochreiter',
#   'JKU',
#   'Linz',
#   'Head',
#   'of',
#   'Institute',
#   'of',
#   'Bioinformatics',
#   '1900',
#   '1940',
#   'Seizing',
#   'the',
#   'Machine',
#   'Learning',
#   'Opportunity',
#   'Ulla',
#   'KruhseLehtonen',
#   'DAIN',
#   'Studios',
#   'CEO',
#   '1940',
#   '2020',
#   'Deep',
#   'Learning',
#   'More',
#   'Than',
#   'Classification',
#   'Calvin',
#   'Seward',
#   'Zalando',
#   'Research',
#   'Scientist',
#   '2020',
#   '2359',
#   'AfterEvent',
#   'Networking',
#   'Snacks',
#   'drinksSponsored',
#   'by',
#   's',
#   'IT',
#   'Solutions',
#   'Austria'],
#  ['The',
#   'Venue',
#   'The',
#   'AI',
#   'Summit',
#   'Vienna',
#   'will',
#   'take',
#   'place',
#   'at',
#   'the',
#   'main',
#   'festival',
#   'hall',
#   'of',
#   'WU',
#   'Wien',
#   's',
#   'Learning',
#   'Center',
#   'depicted',
#   'in',
#   'the',
#   'first',
#   'image',
#   'below'],
#  ['Check', 'Google', 'Maps', 'for', 'directions', 'how', 'to', 'get', 'there'],
#  ['It',
#   'is',
#   'recommended',
#   'to',
#   'arrive',
#   'by',
#   'public',
#   'transport',
#   'with',
#   'the',
#   'nearest',
#   'subway',
#   'stations',
#   'being',
#   'U2',
#   'Krieau',
#   'and',
#   'U2',
#   'MessePrater'],
#  ['Learning',
#   'Center',
#   'WU',
#   'Wiendesigned',
#   'by',
#   'star',
#   'architect',
#   'Zaha',
#   'Hadid',
#   'Tickets',
#   'Attendance',
#   '8',
#   'EUR',
#   'Sold',
#   'Out',
#   'Startup',
#   'Table',
#   '250',
#   'EUR',
#   'Sold',
#   'Out',
#   'Tickets',
#   'grant',
#   'access',
#   'to',
#   'all',
#   'sessions',
#   'coffee',
#   'breaks',
#   'and',
#   'the',
#   'aftersummit',
#   'gettogether'],
#  ['Note',
#   'This',
#   'is',
#   'an',
#   'independent',
#   'volunteerorganized',
#   'notforprofit',
#   'event'],
#  ['We',
#   'set',
#   'the',
#   'price',
#   'as',
#   'low',
#   'as',
#   'possible',
#   'to',
#   'make',
#   'it',
#   'accessible',
#   'for',
#   'everyone'],
#  ['Ticket',
#   'revenues',
#   'will',
#   'solely',
#   'be',
#   'used',
#   'to',
#   'cover',
#   'location',
#   'and',
#   'catering',
#   'costs'],
#  ['All',
#   'our',
#   'speakers',
#   'agreed',
#   'to',
#   'come',
#   'for',
#   'free',
#   'and',
#   'we',
#   'are',
#   'very',
#   'grateful',
#   'for',
#   'their',
#   'support',
#   'of',
#   'our',
#   'community'],
#  ['AfterEvent',
#   'Sponsor',
#   'The',
#   'Organizers',
#   'Michael',
#   'Platzer',
#   'Thomas',
#   'Lidy',
#   'Jan',
#   'Schlüter',
#   'Alex',
#   'Schindler',
#   'Thomas',
#   'Reutterer',
#   'Belinda',
#   'Haid',
#   'Links',
#   'Mostly',
#   'AI',
#   'Vienna',
#   'Deep',
#   'Learning',
#   'Meetup',
#   'Institut',
#   'für',
#   'Service',
#   'Marketing',
#   'Contacts',
#   'summit',
#   'mostlyai',
#   'Further',
#   'Code',
#   'of',
#   'Conduct',
#   '©',
#   '2017',
#   'Based',
#   'on',
#   'Project',
#   'Zeppelin'],
#  ['Designed',
#   'and',
#   'created',
#   'by',
#   'Oleh',
#   'Zasadnyy',
#   '·',
#   'GDG',
#   'Lviv',
#   'Checkin',
#   'Collect',
#   'your',
#   'entrance',
#   'pass'],
#  ['Welcome', 'You', 've', 'made', 'it'],
#  ['Break', 'Snacks', 'drinks'],
#  ['AfterEvent',
#   'Networking',
#   'Snacks',
#   'drinksSponsored',
#   'by',
#   's',
#   'IT',
#   'Solutions',
#   'Austria'],
#  ['Deep',
#   'Learning',
#   'is',
#   'Evolving',
#   'into',
#   'the',
#   'Key',
#   'Technology',
#   'of',
#   'Artificial',
#   'Intelligence',
#   'Deep',
#   'Learning',
#   'has',
#   'emerged',
#   'as',
#   'one',
#   'of',
#   'the',
#   'most',
#   'successful',
#   'fields',
#   'of',
#   'machine',
#   'learning',
#   'and',
#   'artificial',
#   'intelligence',
#   'with',
#   'overwhelming',
#   'success',
#   'in',
#   'industrial',
#   'speech',
#   'language',
#   'and',
#   'vision',
#   'benchmarks'],
#  ['Consequently',
#   'it',
#   'became',
#   'the',
#   'central',
#   'field',
#   'of',
#   'research',
#   'for',
#   'IT',
#   'giants',
#   'like',
#   'Google',
#   'facebook',
#   'Microsoft',
#   'Baidu',
#   'and',
#   'Amazon'],
#  ['Deep',
#   'Learning',
#   'is',
#   'founded',
#   'on',
#   'novel',
#   'neural',
#   'network',
#   'techniques',
#   'the',
#   'recent',
#   'availability',
#   'of',
#   'very',
#   'fast',
#   'computers',
#   'and',
#   'massive',
#   'data',
#   'sets'],
#  ['In',
#   'its',
#   'core',
#   'Deep',
#   'Learning',
#   'discovers',
#   'multiple',
#   'levels',
#   'of',
#   'abstract',
#   'representations',
#   'of',
#   'the',
#   'input'],
#  ['The',
#   'main',
#   'obstacle',
#   'to',
#   'learning',
#   'deep',
#   'neural',
#   'networks',
#   'is',
#   'the',
#   'vanishing',
#   'gradient',
#   'problem'],
#  ['The',
#   'vanishing',
#   'gradient',
#   'impedes',
#   'credit',
#   'assignment',
#   'to',
#   'the',
#   'first',
#   'layers',
#   'of',
#   'a',
#   'deep',
#   'network',
#   'or',
#   'early',
#   'elements',
#   'of',
#   'a',
#   'sequence',
#   'therefore',
#   'limits',
#   'model',
#   'selection'],
#  ['I',
#   'will',
#   'show',
#   'that',
#   'the',
#   'success',
#   'of',
#   'Deep',
#   'Learning',
#   'concepts',
#   'like',
#   'unsupervised',
#   'stacking',
#   'ReLUs',
#   'residual',
#   'networks',
#   'highway',
#   'networks',
#   'and',
#   'LSTM',
#   'can',
#   'be',
#   'traced',
#   'back',
#   'to',
#   'avoiding',
#   'the',
#   'vanishing',
#   'gradient'],
#  ['I',
#   'will',
#   'present',
#   'our',
#   'current',
#   'research',
#   'on',
#   'selfnormalizing',
#   'neural',
#   'networks',
#   'which',
#   'do',
#   'not',
#   'suffer',
#   'for',
#   'exploding',
#   'or',
#   'vanishing',
#   'gradients',
#   'and',
#   'converge',
#   'to',
#   'optimal',
#   'learning',
#   'states'],
#  ['Currently',
#   'we',
#   'advance',
#   'generative',
#   'adversarial',
#   'networks',
#   'GANs',
#   'by',
#   'stochastic',
#   'approximation',
#   'theory',
#   'which',
#   'allows',
#   'proofing',
#   'the',
#   'convergence',
#   'of',
#   'GAN',
#   'learning'],
#  ['In',
#   'the',
#   'AUDI',
#   'Deep',
#   'Learning',
#   'Center',
#   'which',
#   'I',
#   'am',
#   'heading',
#   'we',
#   'apply',
#   'Deep',
#   'Learning',
#   'to',
#   'advance',
#   'autonomous',
#   'driving',
#   'using',
#   'LSTMs',
#   'for',
#   'sequence',
#   'prediction',
#   'and',
#   'for',
#   'attention'],
#  ['We',
#   'use',
#   'it',
#   'or',
#   'natural',
#   'language',
#   'processing',
#   'NLP',
#   'in',
#   'collaboration',
#   'with',
#   'companies',
#   'like',
#   'Zalando',
#   'eg'],
#  ['to', 'analyze', 'fashion', 'blogs'],
#  ['Using',
#   'Deep',
#   'Learning',
#   'we',
#   'won',
#   'the',
#   'NIH',
#   'Tox21',
#   'challenge',
#   'and',
#   'identified',
#   'unknown',
#   'side',
#   'effects',
#   'of',
#   'drug',
#   'candidates',
#   'based',
#   'on',
#   'data',
#   'from',
#   'bioassays',
#   'and',
#   'high',
#   'content',
#   'imaging'],
#  ['Sepp',
#   'Hochreiter',
#   'Head',
#   'of',
#   'Institute',
#   'of',
#   'Bioinformatics',
#   'JKU',
#   'Linz',
#   'Sepp',
#   'Hochreiter',
#   'is',
#   'heading',
#   'the',
#   'Institute',
#   'of',
#   'Bioinformatics',
#   'at',
#   'the',
#   'Johannes',
#   'Kepler',
#   'University',
#   'of',
#   'Linz',
#   'Austria',
#   'and',
#   'works',
#   'in',
#   'the',
#   'fields',
#   'of',
#   'machine',
#   'learning',
#   'and',
#   'bioinformatics'],
#  ['He',
#   'is',
#   'a',
#   'pioneer',
#   'of',
#   'Deep',
#   'Learning',
#   'and',
#   'best',
#   'known',
#   'for',
#   'developing',
#   'the',
#   'long',
#   'short',
#   'term',
#   'memory',
#   'LSTM',
#   'in',
#   'his',
#   'diploma',
#   'thesis',
#   'in',
#   '1991',
#   'which',
#   'has',
#   'been',
#   'published',
#   'later',
#   'in',
#   '1997'],
#  ['Since',
#   '2012',
#   'LSTM',
#   'is',
#   'used',
#   'in',
#   'Google',
#   '’',
#   's',
#   'Android',
#   'speech',
#   'recognizer',
#   'since',
#   '2015',
#   'in',
#   'Google',
#   '’',
#   's',
#   'Voice',
#   'transcription',
#   'since',
#   '2016',
#   'in',
#   'Google',
#   '’',
#   's',
#   'Allo',
#   'and',
#   'since',
#   '2016',
#   'in',
#   'Apple',
#   '’',
#   's',
#   'iOS',
#   '10',
#   'QuickType'],
#  ['Currently',
#   'Sepp',
#   'Hochreiter',
#   'is',
#   'advancing',
#   'the',
#   'theoretical',
#   'foundation',
#   'of',
#   'Deep',
#   'Learning',
#   'by',
#   'analyzing',
#   'gradient',
#   'flow',
#   'through',
#   'deep',
#   'networks',
#   'and',
#   'selfnormalizing',
#   'neural',
#   'networks'],
#  ['Furthermore',
#   'he',
#   'is',
#   'investigating',
#   'unsupervised',
#   'Deep',
#   'Learning',
#   'techniques',
#   'like',
#   'generative',
#   'adversarial',
#   'networks'],
#  ['His',
#   'current',
#   'research',
#   'projects',
#   'include',
#   'Deep',
#   'Learning',
#   'for',
#   'drug',
#   'design',
#   'for',
#   'text',
#   'and',
#   'language',
#   'analysis',
#   'for',
#   'vision',
#   'and',
#   'in',
#   'particular',
#   'for',
#   'autonomous',
#   'driving'],
#  ['Deep',
#   'Learning',
#   'More',
#   'Than',
#   'Classification',
#   'Many',
#   'of',
#   'Deep',
#   'learning',
#   's',
#   'first',
#   'big',
#   'breakthroughs',
#   'were',
#   'in',
#   'the',
#   'field',
#   'of',
#   'classification',
#   'for',
#   'example',
#   'recognizing',
#   'hand',
#   'written',
#   'digits',
#   'or',
#   'imagenet',
#   'images'],
#  ['While',
#   'such',
#   'results',
#   'were',
#   'impressive',
#   'they',
#   'are',
#   'only',
#   'a',
#   'drop',
#   'in',
#   'the',
#   'sea',
#   'of',
#   'possible',
#   'deep',
#   'learning',
#   'applications',
#   'a',
#   'sea',
#   'who',
#   's',
#   'extent',
#   'we',
#   'are',
#   'only',
#   'just',
#   'now',
#   'beginning',
#   'to',
#   'discover'],
#  ['In',
#   'this',
#   'talk',
#   'I',
#   'll',
#   'demonstrate',
#   'a',
#   'sampling',
#   'of',
#   'and',
#   'exciting',
#   'deep',
#   'learning',
#   'applications',
#   'we',
#   're',
#   'working',
#   'on',
#   'at',
#   'Zalando',
#   'in',
#   'cooperation',
#   'with',
#   'Prof',
#   'Dr',
#   'Sepp',
#   'Hochreiter',
#   's',
#   'team',
#   'at',
#   'JKU',
#   'Linz'],
#  ['These',
#   'include',
#   'image',
#   'generation',
#   'with',
#   'Generative',
#   'Adversarial',
#   'Networks',
#   'Semi',
#   'Supervised',
#   'Semantic',
#   'Segmentation',
#   'Warehouse',
#   'Optimization',
#   'and',
#   'Recommender',
#   'Systems'],
#  ['I',
#   'll',
#   'then',
#   'wrap',
#   'up',
#   'with',
#   'a',
#   'few',
#   'technical',
#   'tips',
#   'and',
#   'tricks',
#   'on',
#   'how',
#   'you',
#   'too',
#   'can',
#   'start',
#   'learning',
#   'your',
#   'own',
#   'deep',
#   'neural',
#   'networks'],
#  ['Calvin',
#   'Seward',
#   'Research',
#   'Scientist',
#   'Zalando',
#   'Calvin',
#   'Seward',
#   'is',
#   'a',
#   'Resarch',
#   'Scientist',
#   'in',
#   'Zalando',
#   's',
#   'Research',
#   'Lab',
#   'and',
#   'PhD',
#   'student',
#   'under',
#   'Prof',
#   'Dr',
#   'Sepp',
#   'Hochreiter',
#   'at',
#   'the',
#   'JKU',
#   'Linz',
#   'working',
#   'mainly',
#   'on',
#   'unsupervised',
#   'and',
#   'semisupervised',
#   'computer',
#   'vision',
#   'problems',
#   'including',
#   'classification',
#   'localization',
#   'semantic',
#   'segmentation',
#   'and',
#   'image',
#   'generation'],
#  ['The',
#   'main',
#   'line',
#   'of',
#   'attack',
#   'for',
#   'these',
#   'problems',
#   'is',
#   'deep',
#   'neural',
#   'networks',
#   'written',
#   'in',
#   'the',
#   'Tensorflow',
#   'framework',
#   'and',
#   'trained',
#   'on',
#   'GPU',
#   'clusters'],
#  ['At',
#   'the',
#   'same',
#   'time',
#   'he',
#   'is',
#   'involved',
#   'in',
#   'applying',
#   'lessons',
#   'from',
#   'GPUdriven',
#   'HPC',
#   'computing',
#   'and',
#   'cutting',
#   'edge',
#   'Machine',
#   'Learning',
#   'to',
#   'other',
#   'fields',
#   'of',
#   'the',
#   'Zalando',
#   'universe'],
#  ['Past',
#   'projects',
#   'have',
#   'included',
#   'sizing',
#   'solutions',
#   'for',
#   'online',
#   'retail',
#   'warehouse',
#   'management',
#   'and',
#   'recommendation',
#   'systems'],
#  ['Seizing',
#   'the',
#   'Machine',
#   'Learning',
#   'Opportunity',
#   'Gartner',
#   'predicts',
#   '2017',
#   'to',
#   'be',
#   'the',
#   'year',
#   'when',
#   'Machine',
#   'Learning',
#   'reaches',
#   'its',
#   'peak',
#   'in',
#   'terms',
#   'of',
#   'inflated',
#   'expectations'],
#  ['This',
#   'is',
#   'the',
#   'right',
#   'time',
#   'to',
#   'not',
#   'only',
#   'talk',
#   'about',
#   'the',
#   'sea',
#   'of',
#   'opportunity',
#   'but',
#   'also',
#   'provide',
#   'a',
#   'nononsense',
#   'view',
#   'of',
#   'the',
#   'practical',
#   'obstacles',
#   'which',
#   'organizations',
#   'will',
#   'encounter',
#   'on',
#   'their',
#   'path',
#   'to',
#   'seizing',
#   'them'],
#  ['In',
#   'this',
#   'talk',
#   'I',
#   'll',
#   'cover',
#   'these',
#   'topics',
#   'from',
#   'a',
#   'managerial',
#   'perspective',
#   'Machine',
#   'Learning',
#   'use',
#   'cases',
#   'from',
#   'the',
#   'industry',
#   'Factors',
#   'of',
#   'success',
#   'and',
#   'nonsuccess',
#   'Ideation',
#   'process',
#   'for',
#   'data',
#   'products',
#   'Efficient',
#   'organizational',
#   'setup',
#   'Recruiting',
#   'retaining',
#   'of',
#   'data',
#   'scientists',
#   'Ulla',
#   'KruhseLehtonen',
#   'CEO',
#   'DAIN',
#   'Studios',
#   'Ulla',
#   'is',
#   'the',
#   'CEO',
#   'of',
#   'DAIN',
#   'Studios',
#   'a',
#   'rapidly',
#   'growing',
#   'Data',
#   'and',
#   'Artificial',
#   'Intelligence',
#   'consulting',
#   'product',
#   'startup',
#   'operating',
#   'in',
#   'Finland',
#   'and',
#   'DACH'],
#  ['She',
#   'started',
#   'her',
#   'career',
#   'as',
#   'a',
#   'microeconomist',
#   'moved',
#   'into',
#   'management',
#   'and',
#   'economics',
#   'consulting',
#   'at',
#   'the',
#   'turn',
#   'of',
#   'the',
#   'century',
#   'focusing',
#   'on',
#   'a',
#   'variety',
#   'of',
#   'topics',
#   'such',
#   'as',
#   'supply',
#   'chain',
#   'optimization',
#   'telco',
#   'billing',
#   'systems',
#   'analytical',
#   'CRM',
#   'and',
#   'econometric',
#   'evaluations',
#   'of',
#   'international',
#   'organizations'],
#  ['In',
#   '2008',
#   'she',
#   'moved',
#   'to',
#   'the',
#   'client',
#   'side',
#   'and',
#   'has',
#   'launched',
#   'developed',
#   'and',
#   'led',
#   'Consumer',
#   'Analytics',
#   'functions',
#   'in',
#   'two',
#   'large',
#   'companies'],
#  ['At',
#   'Nokia',
#   'she',
#   'established',
#   'the',
#   'global',
#   'Consumer',
#   'Analytics',
#   'Department',
#   'with',
#   'over',
#   '30',
#   'data',
#   'scientists',
#   'providing',
#   'support',
#   'in',
#   'sales',
#   'and',
#   'marketing',
#   'supply',
#   'chain',
#   'and',
#   'product',
#   'analytics',
#   'to',
#   'Nokia',
#   '’',
#   's',
#   '70',
#   'local',
#   'operations'],
#  ['At',
#   'Sanoma',
#   'as',
#   'Vice',
#   'President',
#   'for',
#   'Consumer',
#   'Analytics',
#   'and',
#   'Insights',
#   'Ulla',
#   'established',
#   'and',
#   'led',
#   'the',
#   'Analytics',
#   'Center',
#   'of',
#   'Excellence',
#   'a',
#   '45person',
#   'unit',
#   'operating',
#   'in',
#   'Finland',
#   'and',
#   'the',
#   'Netherlands',
#   'serving',
#   'Sanoma',
#   '’',
#   's',
#   'media',
#   'and',
#   'learning',
#   'business'],
#  ['In',
#   '2013',
#   'Ulla',
#   'was',
#   'recognized',
#   'as',
#   'the',
#   'Information',
#   'Leader',
#   'of',
#   'the',
#   'Year',
#   'in',
#   'Finland'],
#  ['She',
#   'holds',
#   'a',
#   'PhD',
#   'in',
#   'Economics',
#   'from',
#   'the',
#   'Helsinki',
#   'School',
#   'of',
#   'Economics',
#   'Aalto',
#   'University'],
#  ['Machine',
#   'Learning',
#   'with',
#   'Google',
#   'Cloud',
#   'Artificial',
#   'intelligence',
#   'and',
#   'machine',
#   'learning',
#   'has',
#   'great',
#   'potential',
#   'to',
#   'improve',
#   'our',
#   'lives'],
#  ['Google',
#   'has',
#   'made',
#   'machine',
#   'learning',
#   'a',
#   'central',
#   'part',
#   'of',
#   'how',
#   'they',
#   'design',
#   'services',
#   'and',
#   'Google',
#   'Cloud',
#   'has',
#   'developed',
#   'several',
#   'ways',
#   'for',
#   'both',
#   'data',
#   'scientist',
#   'and',
#   'software',
#   'developers',
#   'to',
#   'realize',
#   'that',
#   'potential'],
#  ['In',
#   'this',
#   'session',
#   'we',
#   'will',
#   'walk',
#   'through',
#   'examples',
#   'of',
#   'how',
#   'Google',
#   'uses',
#   'machine',
#   'learning',
#   'internally',
#   'and',
#   'then',
#   'introduce',
#   'different',
#   'ways',
#   'people',
#   'are',
#   'working',
#   'with',
#   'Google',
#   'and',
#   'Google',
#   'Cloud',
#   'including',
#   'TensorFlow',
#   'an',
#   'opensource',
#   'machine',
#   'learning',
#   'platform',
#   'that',
#   'is',
#   'fast',
#   'flexible',
#   'and',
#   'productionready',
#   'and',
#   'scales',
#   'from',
#   'research',
#   'to',
#   'production'],
#  ['Google',
#   'Cloud',
#   'Machine',
#   'Learning',
#   'Engine',
#   'a',
#   'managed',
#   'service',
#   'that',
#   'enables',
#   'you',
#   'to',
#   'build',
#   'machine',
#   'learning',
#   'models',
#   'that',
#   'work',
#   'on',
#   'any',
#   'type',
#   'of',
#   'data',
#   'of',
#   'any',
#   'size'],
#  ['APIs',
#   'pretrained',
#   'models',
#   'available',
#   'via',
#   'application',
#   'programming',
#   'interfaces',
#   'APIs',
#   'that',
#   'allow',
#   'software',
#   'developers',
#   'to',
#   'realize',
#   'ML',
#   'benefits',
#   'in',
#   'domains',
#   'such',
#   'as',
#   'image',
#   'analysis',
#   'video',
#   'analysis',
#   'speech',
#   'recognition',
#   'text',
#   'analysis',
#   'and',
#   'dynamic',
#   'translation'],
#  ['Dave',
#   'Elliott',
#   'Global',
#   'Product',
#   'Lead',
#   'Google',
#   'Dave',
#   'Elliott',
#   'is',
#   'a',
#   'technology',
#   'evangelist',
#   'and',
#   'an',
#   'Architect',
#   'Advocate',
#   'for',
#   'cloud',
#   'platform',
#   'at',
#   'Google'],
#  ['In',
#   'this',
#   'role',
#   'he',
#   'engages',
#   'communities',
#   'to',
#   'inspire',
#   'them',
#   'to',
#   'try',
#   'new',
#   'products',
#   'and',
#   'technologies',
#   'embrace',
#   'new',
#   'ideas',
#   'and',
#   'he',
#   'is',
#   'the',
#   'voice',
#   'of',
#   'those',
#   'communities',
#   'to',
#   'product',
#   'and',
#   'engineering',
#   'teams'],
#  ['Prior',
#   'to',
#   'Google',
#   'Elliott',
#   'was',
#   'a',
#   'Chief',
#   'Cloud',
#   'Evangelist',
#   'at',
#   'Symantec',
#   'where',
#   'he',
#   'advocated',
#   'for',
#   'new',
#   'architectures',
#   'in',
#   'data',
#   'and',
#   'storage'],
#  ['Mr',
#   'Elliott',
#   'was',
#   'an',
#   'early',
#   'advocate',
#   'of',
#   'cloud',
#   'computing',
#   'while',
#   'at',
#   'Sun',
#   'Microsystems',
#   'in',
#   'the',
#   '1990s',
#   'and',
#   'has',
#   'spent',
#   'his',
#   'career',
#   'helping',
#   'companies',
#   'understand',
#   'and',
#   'embrace',
#   'emerging',
#   'technologies'],
#  ['Mr',
#   'Elliott',
#   'holds',
#   'an',
#   'MBA',
#   'from',
#   'the',
#   'University',
#   'of',
#   'California',
#   'at',
#   'Berkeley',
#   'and',
#   'an',
#   'BA',
#   'in',
#   'Quantitative',
#   'Economics',
#   'Decision',
#   'Sciences',
#   'from',
#   'the',
#   'University',
#   'of',
#   'California',
#   'San',
#   'Diego'],
#  ['Neural',
#   'Networks',
#   'for',
#   'Natural',
#   'Language',
#   'Processing',
#   'Artificial',
#   'neural',
#   'networks',
#   'are',
#   'currently',
#   'very',
#   'successful',
#   'in',
#   'various',
#   'machine',
#   'learning',
#   'tasks',
#   'that',
#   'involve',
#   'natural',
#   'language'],
#  ['In',
#   'this',
#   'talk',
#   'I',
#   'will',
#   'describe',
#   'recurrent',
#   'neural',
#   'network',
#   'language',
#   'models',
#   'as',
#   'well',
#   'as',
#   'their',
#   'most',
#   'frequent',
#   'applications',
#   'to',
#   'speech',
#   'recognition',
#   'and',
#   'machine',
#   'translation'],
#  ['I',
#   'will',
#   'also',
#   'talk',
#   'about',
#   'distributed',
#   'word',
#   'representations',
#   'their',
#   'interesting',
#   'properties',
#   'and',
#   'efficient',
#   'ways',
#   'how',
#   'to',
#   'compute',
#   'them',
#   'and',
#   'use',
#   'in',
#   'tasks',
#   'such',
#   'as',
#   'text',
#   'classification'],
#  ['Finally',
#   'I',
#   'will',
#   'describe',
#   'our',
#   'latest',
#   'efforts',
#   'to',
#   'create',
#   'a',
#   'novel',
#   'dataset',
#   'that',
#   'could',
#   'be',
#   'used',
#   'to',
#   'develop',
#   'machines',
#   'that',
#   'can',
#   'truly',
#   'communicate',
#   'with',
#   'human',
#   'users',
#   'in',
#   'natural',
#   'language'],
#  ['Tomáš',
#   'Mikolov',
#   'AI',
#   'Research',
#   'Scientist',
#   'Facebook',
#   'Tomáš',
#   'Mikolov',
#   'is',
#   'a',
#   'research',
#   'scientist',
#   'at',
#   'Facebook',
#   'AI',
#   'Research',
#   'group',
#   'since',
#   '2014'],
#  ['Previously',
#   'he',
#   'has',
#   'been',
#   'member',
#   'of',
#   'the',
#   'Google',
#   'Brain',
#   'team',
#   'where',
#   'he',
#   'developed',
#   'and',
#   'implemented',
#   'efficient',
#   'algorithms',
#   'for',
#   'computing',
#   'distributed',
#   'representations',
#   'of',
#   'words',
#   'the',
#   'word2vec',
#   'project'],
#  ['He',
#   'obtained',
#   'his',
#   'PhD',
#   'from',
#   'the',
#   'Brno',
#   'University',
#   'of',
#   'Technology',
#   'Czech',
#   'Republic',
#   'in',
#   '2012',
#   'for',
#   'his',
#   'work',
#   'on',
#   'recurrent',
#   'neural',
#   'networkbased',
#   'language',
#   'models',
#   'RNNLM'],
#  ['His',
#   'long',
#   'term',
#   'research',
#   'goal',
#   'is',
#   'to',
#   'develop',
#   'intelligent',
#   'machines',
#   'that',
#   'people',
#   'can',
#   'communicate',
#   'with',
#   'and',
#   'use',
#   'to',
#   'accomplish',
#   'complex',
#   'tasks'],
#  ['function',
#   'i',
#   's',
#   'o',
#   'g',
#   'r',
#   'a',
#   'm',
#   'i',
#   'GoogleAnalyticsObject',
#   'r',
#   'i',
#   'r',
#   'i',
#   'r',
#   'function',
#   'i',
#   'r',
#   'qi',
#   'r',
#   'q',
#   'push',
#   'arguments',
#   'i',
#   'r',
#   'l1new',
#   'Date',
#   'ascreateElement',
#   'o',
#   'msgetElementsByTagName',
#   'o',
#   '0',
#   'aasync1',
#   'asrcg',
#   'mparentNodeinsertBefore',
#   'a',
#   'm',
#   'window',
#   'document',
#   'script',
#   'wwwgoogleanalyticscomanalyticsjs',
#   'ga',
#   'ga',
#   'create',
#   'UA913981971',
#   'mostlyaisummit',
#   'ga',
#   'send',
#   'pageview',
#   'windowjQuery',
#   'documentwrite',
#   'script',
#   'src',
#   'summitjsjquery211minjs',
#   'script',
#   'if',
#   'typeof',
#   'fnmodal',
#   'undefined',
#   'documentwrite',
#   'script',
#   'src',
#   'summitjsbootstrapminjs',
#   'script',
#   'WavesdisplayEffect',
#   'var',
#   'twitterFeedUrl',
#   'document',
#   'ready',
#   'function',
#   'function',
#   'if',
#   'window',
#   'width',
#   '767',
#   'typeouttext',
#   'typed',
#   'strings',
#   'typeSpeed',
#   '150',
#   'backDelay',
#   '900',
#   'loop',
#   'true',
#   'var',
#   'rockstarSpeakers',
#   'name',
#   'Sepp',
#   'Hochreiter',
#   'company',
#   'JKU',
#   'Linz',
#   'Head',
#   'of',
#   'Institute',
#   'of',
#   'Bioinformatics',
#   'image',
#   'summitimgpeopleSeppHochreiterjpg',
#   'name',
#   'Calvin',
#   'Seward',
#   'company',
#   'Zalando',
#   'Research',
#   'Scientist',
#   'image',
#   'summitimgpeopleCalvinSewardjpg',
#   'name',
#   'Ulla',
#   'KruhseLehtonen',
#   'company',
#   'DAIN',
#   'Studios',
#   'CEO',
#   'image',
#   'summitimgpeopleUllaKruhseLehtonenjpg',
#   'name',
#   'Dave',
#   'Elliott',
#   'company',
#   'Google',
#   'Global',
#   'Product',
#   'Lead',
#   'image',
#   'summitimgpeopleDaveElliotjpg',
#   'name',
#   'Tomáš',
#   'Mikolov',
#   'company',
#   'Facebook',
#   'AI',
#   'Research',
#   'Scientist',
#   'image',
#   'summitimgpeopleThomasMikolovjpg',
#   'rockstarSpeakerssort',
#   'function',
#   'return',
#   '05',
#   'Mathrandom',
#   'if',
#   'rockstarSpeakerslength',
#   '0',
#   'var',
#   'animationDelay',
#   '1500',
#   'count',
#   'Mathmin',
#   '5',
#   'rockstarSpeakerslength',
#   'colWidth',
#   '12count',
#   'for',
#   'i0',
#   'i',
#   'count',
#   'i',
#   'var',
#   'clearfix',
#   'div',
#   'class',
#   'clearfix',
#   'visiblexs',
#   'div',
#   'if',
#   'i',
#   '2',
#   '0',
#   'clearfix',
#   'rockstarspeakertitle',
#   'after',
#   'div',
#   'class',
#   'colmd',
#   'colWidth',
#   'colxs6',
#   'rockstarspeakersitem',
#   'animated',
#   'hiding',
#   'dataanimation',
#   'fadeInUp',
#   'datadelay',
#   'animationDelay',
#   'div',
#   'class',
#   'rockstarspeaker',
#   'div',
#   'class',
#   'flowimg',
#   'imgcircle',
#   'rockstarspeakerimg',
#   'style',
#   'backgroundimage',
#   'url',
#   'rockstarSpeakers',
#   'i',
#   'image',
#   'div',
#   'div',
#   'class',
#   'name',
#   'rockstarSpeakers',
#   'i',
#   'name',
#   'div',
#   'div',
#   'class',
#   'sub',
#   'rockstarSpeakers',
#   'i',
#   'company',
#   'div',
#   'div',
#   'div',
#   'clearfix',
#   'animationDelay',
#   '500',
#   'context',
#   'http',
#   'schemaorg',
#   'type',
#   'Event',
#   'name',
#   'AI',
#   'Summit',
#   'Vienna',
#   'description',
#   'AI',
#   'Summit',
#   'Vienna',
#   'image',
#   'https',
#   'mostlyaigithubiosummitimgseosharinggooglepluspng',
#   'url',
#   'https',
#   'mostlyaigithubio',
#   'startDate',
#   '20170904T0900',
#   'doorTime',
#   '0900',
#   'endDate',
#   '20170904T2100',
#   'location',
#   'type',
#   'Place',
#   'name',
#   'Learning',
#   'Center',
#   'WU',
#   'Campus',
#   'sameAs',
#   'https',
#   'googlmapsM7rdWybAQM62',
#   'address',
#   'type',
#   'PostalAddress',
#   'streetAddress',
#   'Welthandelsplatz',
#   '1',
#   '1',
#   '1020',
#   'Wien',
#   'Austria',
#   'addressLocality',
#   'Vienna',
#   'addressRegion',
#   'postalCode',
#   '1020',
#   'addressCountry',
#   'Austria',
#   'geo',
#   'type',
#   'GeoCoordinates',
#   'latitude',
#   '482141753',
#   'longitude',
#   '164068405',
#   'Not',
#   'supported',
#   'yet',
#   'organizer',
#   'type',
#   'Organization',
#   'name',
#   'Mostly',
#   'AI',
#   'the',
#   'Vienna',
#   'Deep',
#   'Learning',
#   'Meetup',
#   'alternateName',
#   'Mostly',
#   'AI',
#   'the',
#   'Vienna',
#   'Deep',
#   'Learning',
#   'Meetup',
#   'description',
#   'logo',
#   'https',
#   'mostlyaigithubiosummitimgseoorganizerlogopng',
#   'email',
#   'summit',
#   'mostlyai',
#   'sameAs',
#   'http',
#   'mostlyai',
#   'subEvent',
#   'type',
#   'Event',
#   'name',
#   'description',
#   'image',
#   'https',
#   'mostlyaigithubiosummitimgseosharinggooglepluspng',
#   'url',
#   'https',
#   'mostlyaigithubiosummithackathon',
#   'startDate',
#   'doorTime',
#   'endDate',
#   'location',
#   'type',
#   'Place',
#   'name',
#   'sameAs',
#   'address',
#   'type',
#   'PostalAddress',
#   'streetAddress',
#   'addressLocality',
#   'addressRegion',
#   'postalCode',
#   'addressCountry',
#   'geo',
#   'type',
#   'GeoCoordinates',
#   'latitude',
#   'longitude',
#   'offers',
#   'type',
#   'Offer',
#   'name',
#   'Attendance',
#   'url',
#   'https',
#   'wwweventbritecomeaisummitviennatickets33993018032',
#   'price',
#   '8',
#   'priceCurrency',
#   'EUR',
#   'validFrom',
#   'validThrough',
#   'type',
#   'Offer',
#   'name',
#   'Startup',
#   'Table',
#   'url',
#   'http',
#   'mostlyaisummitassetsAISummitViennaStartupTablepdf',
#   'price',
#   '250',
#   'priceCurrency',
#   'EUR',
#   'validFrom',
#   'validThrough',
#   'performer',
#   'type',
#   'Person',
#   'name',
#   'Sepp',
#   'Hochreiter',
#   'image',
#   'https',
#   'mostlyaigithubiosummitimgpeopleSeppHochreiterjpg',
#   'jobTitle',
#   'Head',
#   'of',
#   'Institute',
#   'of',
#   'Bioinformatics',
#   'worksFor',
#   'type',
#   'Organization',
#   'name',
#   'JKU',
#   'Linz',
#   'sameAs',
#   'http',
#   'wwwbioinfjkuatpeoplehochreiter',
#   'type',
#   'Person',
#   'name',
#   'Calvin',
#   'Seward',
#   'image',
#   'https',
#   'mostlyaigithubiosummitimgpeopleCalvinSewardjpg',
#   'jobTitle',
#   'Research',
#   'Scientist',
#   'worksFor',
#   'type',
#   'Organization',
#   'name',
#   'Zalando',
#   'sameAs',
#   'https',
#   'wwwlinkedincomincalvinseward',
#   'type',
#   'Person',
#   'name',
#   'Ulla',
#   'KruhseLehtonen',
#   'image',
#   'https',
#   'mostlyaigithubiosummitimgpeopleUllaKruhseLehtonenjpg',
#   'jobTitle',
#   'CEO',
#   'worksFor',
#   'type',
#   'Organization',
#   'name',
#   'DAIN',
#   'Studios',
#   'sameAs',
#   'http',
#   'wwwdainstudioscom',
#   'type',
#   'Person',
#   'name',
#   'Dave',
#   'Elliott',
#   'image',
#   'https',
#   'mostlyaigithubiosummitimgpeopleDaveElliotjpg',
#   'jobTitle',
#   'Global',
#   'Product',
#   'Lead',
#   'worksFor',
#   'type',
#   'Organization',
#   'name',
#   'Google',
#   'sameAs',
#   'https',
#   'wwwlinkedincomindavidlelliott',
#   'type',
#   'Person',
#   'name',
#   'Tomáš',
#   'Mikolov',
#   'image',
#   'https',
#   'mostlyaigithubiosummitimgpeopleThomasMikolovjpg',
#   'jobTitle',
#   'AI',
#   'Research',
#   'Scientist',
#   'worksFor',
#   'type',
#   'Organization',
#   'name',
#   'Facebook',
#   'sameAs',
#   'https',
#   'researchfbcompeoplemikolovtomas',
#   'eventStatus',
#   'EventScheduled',
#   'typicalAgeRange',
#   '16']]

# %%
cleaned_text = clean_text(text, language='english', stopwords=True, punctuation=True)

# %% [markdown]
# ### Applying Word Stemming and Lemmatization

# %%
def stem_text(text, language='english', lemmatize=True, stemmer='porter'):
    """
    Creates a stemmed or lemmatized version of the input text for downstream analysis.
    
    Given a word_sentence tokenized text it returns the stemmed version of the text.
    """
    if lemmatize:
        from nltk.stem.wordnet import WordNetLemmatizer
        stem = WordNetLemmatizer()
        return [[stem.lemmatize(word) for word in sent] for sent in text]
    
    elif stemmer == 'porter':
        from nltk.stem.porter import PorterStemmer
        stem = PorterStemmer()
    elif stemmer == 'snowball':
        from nltk.stem.snowball import SnowballStemmer
        stem = SnowballStemmer(language)
    
    # Apply the chosen stemmer to the Text
    return [[stem.stem(word) for word in sent] for sent in text]

# %%
# Creating a stemmed Version of the Text
stem_text(cleaned_text, language='english', lemmatize=True, stemmer='porter')
# Out:
# [['AI',
#   'Summit',
#   'Vienna',
#   'AI',
#   'Advances',
#   'Insights',
#   'on',
#   'the',
#   'latest',
#   'advance',
#   'in',
#   'the',
#   'field',
#   'and',
#   'where',
#   'we',
#   'are',
#   'heading'],
#  ['Deep',
#   'Learning',
#   'Dive',
#   'into',
#   'the',
#   'powerful',
#   'model',
#   'class',
#   'that',
#   'are',
#   'behind',
#   'the',
#   'current',
#   'AI',
#   'revival'],
#  ['ML',
#   'Use',
#   'Cases',
#   'Realworld',
#   'application',
#   'of',
#   'machine',
#   'learning',
#   'shared',
#   'by',
#   'seasoned',
#   'practitioner'],
#  ['Networking',
#   'Informal',
#   'gettogether',
#   'of',
#   'AI',
#   'enthusiast',
#   'at',
#   'one',
#   'of',
#   'Europe',
#   's',
#   'most',
#   'modern',
#   'campus'],
#  ['Learn',
#   'from',
#   'Leading',
#   'AI',
#   'Experts',
#   'Selflearning',
#   'machine',
#   'are',
#   'outperforming',
#   'human',
#   'in',
#   'decision',
#   'making',
#   'at',
#   'an',
#   'ever',
#   'increasing',
#   'pace'],
#  ['These',
#   'ongoing',
#   'advancement',
#   'are',
#   'fueled',
#   'by',
#   '1',
#   'more',
#   'efficient',
#   'algorithm',
#   '2',
#   'faster',
#   'processing',
#   'power',
#   'and',
#   '3',
#   'an',
#   'expontential',
#   'growth',
#   'in',
#   'data'],
#  ['By',
#   'bringing',
#   'together',
#   'leading',
#   'AI',
#   'researcher',
#   'and',
#   'practitioner',
#   'here',
#   'in',
#   'Vienna',
#   'we',
#   'will',
#   'have',
#   'the',
#   'unique',
#   'opportunity',
#   'to',
#   'go',
#   'beyond',
#   'the',
#   'hype',
#   'and',
#   'gain',
#   'a',
#   'practical',
#   'understanding',
#   'of',
#   'artificial',
#   'intelligence',
#   'it',
#   'potential',
#   'a',
#   'well',
#   'a',
#   'it',
#   'underlying',
#   'algorithm'],
#  ['Our',
#   'Promise',
#   'a',
#   'nonprofit',
#   'contentrich',
#   'AI',
#   'Summit',
#   'tailored',
#   'to',
#   'a',
#   'forwardthinking',
#   'and',
#   'techsavvy',
#   'audience',
#   'Program',
#   'Note',
#   'We',
#   'will',
#   'use',
#   'slidocom',
#   'to',
#   'manage',
#   'Q',
#   'A',
#   'session',
#   'after',
#   'the',
#   'talk'],
#  ['Feel',
#   'free',
#   'to',
#   'post',
#   'and',
#   'vote',
#   'question',
#   'at',
#   'http',
#   'appslidoeventfzxgjgkkask'],
#  ['And',
#   'in',
#   'case',
#   'you',
#   'feel',
#   'like',
#   'sharing',
#   'online',
#   'the',
#   'official',
#   'hashtag',
#   'of',
#   'the',
#   'event',
#   'is',
#   'AISV17'],
#  ['September',
#   '04',
#   'AI',
#   'Summit',
#   'Vienna',
#   '1530',
#   '1600',
#   'Checkin',
#   'Collect',
#   'your',
#   'entrance',
#   'pas'],
#  ['1600', '1620', 'Welcome', 'You', 've', 'made', 'it'],
#  ['1620',
#   '1700',
#   'Machine',
#   'Learning',
#   'with',
#   'Google',
#   'Cloud',
#   'Dave',
#   'Elliott',
#   'Google',
#   'Global',
#   'Product',
#   'Lead',
#   '1700',
#   '1740',
#   'Neural',
#   'Networks',
#   'for',
#   'Natural',
#   'Language',
#   'Processing',
#   'Tomáš',
#   'Mikolov',
#   'Facebook',
#   'AI',
#   'Research',
#   'Scientist',
#   '1740',
#   '1820',
#   'Break',
#   'Snacks',
#   'drink'],
#  ['1820',
#   '1900',
#   'Deep',
#   'Learning',
#   'is',
#   'Evolving',
#   'into',
#   'the',
#   'Key',
#   'Technology',
#   'of',
#   'Artificial',
#   'Intelligence',
#   'Sepp',
#   'Hochreiter',
#   'JKU',
#   'Linz',
#   'Head',
#   'of',
#   'Institute',
#   'of',
#   'Bioinformatics',
#   '1900',
#   '1940',
#   'Seizing',
#   'the',
#   'Machine',
#   'Learning',
#   'Opportunity',
#   'Ulla',
#   'KruhseLehtonen',
#   'DAIN',
#   'Studios',
#   'CEO',
#   '1940',
#   '2020',
#   'Deep',
#   'Learning',
#   'More',
#   'Than',
#   'Classification',
#   'Calvin',
#   'Seward',
#   'Zalando',
#   'Research',
#   'Scientist',
#   '2020',
#   '2359',
#   'AfterEvent',
#   'Networking',
#   'Snacks',
#   'drinksSponsored',
#   'by',
#   's',
#   'IT',
#   'Solutions',
#   'Austria'],
#  ['The',
#   'Venue',
#   'The',
#   'AI',
#   'Summit',
#   'Vienna',
#   'will',
#   'take',
#   'place',
#   'at',
#   'the',
#   'main',
#   'festival',
#   'hall',
#   'of',
#   'WU',
#   'Wien',
#   's',
#   'Learning',
#   'Center',
#   'depicted',
#   'in',
#   'the',
#   'first',
#   'image',
#   'below'],
#  ['Check', 'Google', 'Maps', 'for', 'direction', 'how', 'to', 'get', 'there'],
#  ['It',
#   'is',
#   'recommended',
#   'to',
#   'arrive',
#   'by',
#   'public',
#   'transport',
#   'with',
#   'the',
#   'nearest',
#   'subway',
#   'station',
#   'being',
#   'U2',
#   'Krieau',
#   'and',
#   'U2',
#   'MessePrater'],
#  ['Learning',
#   'Center',
#   'WU',
#   'Wiendesigned',
#   'by',
#   'star',
#   'architect',
#   'Zaha',
#   'Hadid',
#   'Tickets',
#   'Attendance',
#   '8',
#   'EUR',
#   'Sold',
#   'Out',
#   'Startup',
#   'Table',
#   '250',
#   'EUR',
#   'Sold',
#   'Out',
#   'Tickets',
#   'grant',
#   'access',
#   'to',
#   'all',
#   'session',
#   'coffee',
#   'break',
#   'and',
#   'the',
#   'aftersummit',
#   'gettogether'],
#  ['Note',
#   'This',
#   'is',
#   'an',
#   'independent',
#   'volunteerorganized',
#   'notforprofit',
#   'event'],
#  ['We',
#   'set',
#   'the',
#   'price',
#   'a',
#   'low',
#   'a',
#   'possible',
#   'to',
#   'make',
#   'it',
#   'accessible',
#   'for',
#   'everyone'],
#  ['Ticket',
#   'revenue',
#   'will',
#   'solely',
#   'be',
#   'used',
#   'to',
#   'cover',
#   'location',
#   'and',
#   'catering',
#   'cost'],
#  ['All',
#   'our',
#   'speaker',
#   'agreed',
#   'to',
#   'come',
#   'for',
#   'free',
#   'and',
#   'we',
#   'are',
#   'very',
#   'grateful',
#   'for',
#   'their',
#   'support',
#   'of',
#   'our',
#   'community'],
#  ['AfterEvent',
#   'Sponsor',
#   'The',
#   'Organizers',
#   'Michael',
#   'Platzer',
#   'Thomas',
#   'Lidy',
#   'Jan',
#   'Schlüter',
#   'Alex',
#   'Schindler',
#   'Thomas',
#   'Reutterer',
#   'Belinda',
#   'Haid',
#   'Links',
#   'Mostly',
#   'AI',
#   'Vienna',
#   'Deep',
#   'Learning',
#   'Meetup',
#   'Institut',
#   'für',
#   'Service',
#   'Marketing',
#   'Contacts',
#   'summit',
#   'mostlyai',
#   'Further',
#   'Code',
#   'of',
#   'Conduct',
#   '©',
#   '2017',
#   'Based',
#   'on',
#   'Project',
#   'Zeppelin'],
#  ['Designed',
#   'and',
#   'created',
#   'by',
#   'Oleh',
#   'Zasadnyy',
#   '·',
#   'GDG',
#   'Lviv',
#   'Checkin',
#   'Collect',
#   'your',
#   'entrance',
#   'pas'],
#  ['Welcome', 'You', 've', 'made', 'it'],
#  ['Break', 'Snacks', 'drink'],
#  ['AfterEvent',
#   'Networking',
#   'Snacks',
#   'drinksSponsored',
#   'by',
#   's',
#   'IT',
#   'Solutions',
#   'Austria'],
#  ['Deep',
#   'Learning',
#   'is',
#   'Evolving',
#   'into',
#   'the',
#   'Key',
#   'Technology',
#   'of',
#   'Artificial',
#   'Intelligence',
#   'Deep',
#   'Learning',
#   'ha',
#   'emerged',
#   'a',
#   'one',
#   'of',
#   'the',
#   'most',
#   'successful',
#   'field',
#   'of',
#   'machine',
#   'learning',
#   'and',
#   'artificial',
#   'intelligence',
#   'with',
#   'overwhelming',
#   'success',
#   'in',
#   'industrial',
#   'speech',
#   'language',
#   'and',
#   'vision',
#   'benchmark'],
#  ['Consequently',
#   'it',
#   'became',
#   'the',
#   'central',
#   'field',
#   'of',
#   'research',
#   'for',
#   'IT',
#   'giant',
#   'like',
#   'Google',
#   'facebook',
#   'Microsoft',
#   'Baidu',
#   'and',
#   'Amazon'],
#  ['Deep',
#   'Learning',
#   'is',
#   'founded',
#   'on',
#   'novel',
#   'neural',
#   'network',
#   'technique',
#   'the',
#   'recent',
#   'availability',
#   'of',
#   'very',
#   'fast',
#   'computer',
#   'and',
#   'massive',
#   'data',
#   'set'],
#  ['In',
#   'it',
#   'core',
#   'Deep',
#   'Learning',
#   'discovers',
#   'multiple',
#   'level',
#   'of',
#   'abstract',
#   'representation',
#   'of',
#   'the',
#   'input'],
#  ['The',
#   'main',
#   'obstacle',
#   'to',
#   'learning',
#   'deep',
#   'neural',
#   'network',
#   'is',
#   'the',
#   'vanishing',
#   'gradient',
#   'problem'],
#  ['The',
#   'vanishing',
#   'gradient',
#   'impedes',
#   'credit',
#   'assignment',
#   'to',
#   'the',
#   'first',
#   'layer',
#   'of',
#   'a',
#   'deep',
#   'network',
#   'or',
#   'early',
#   'element',
#   'of',
#   'a',
#   'sequence',
#   'therefore',
#   'limit',
#   'model',
#   'selection'],
#  ['I',
#   'will',
#   'show',
#   'that',
#   'the',
#   'success',
#   'of',
#   'Deep',
#   'Learning',
#   'concept',
#   'like',
#   'unsupervised',
#   'stacking',
#   'ReLUs',
#   'residual',
#   'network',
#   'highway',
#   'network',
#   'and',
#   'LSTM',
#   'can',
#   'be',
#   'traced',
#   'back',
#   'to',
#   'avoiding',
#   'the',
#   'vanishing',
#   'gradient'],
#  ['I',
#   'will',
#   'present',
#   'our',
#   'current',
#   'research',
#   'on',
#   'selfnormalizing',
#   'neural',
#   'network',
#   'which',
#   'do',
#   'not',
#   'suffer',
#   'for',
#   'exploding',
#   'or',
#   'vanishing',
#   'gradient',
#   'and',
#   'converge',
#   'to',
#   'optimal',
#   'learning',
#   'state'],
#  ['Currently',
#   'we',
#   'advance',
#   'generative',
#   'adversarial',
#   'network',
#   'GANs',
#   'by',
#   'stochastic',
#   'approximation',
#   'theory',
#   'which',
#   'allows',
#   'proofing',
#   'the',
#   'convergence',
#   'of',
#   'GAN',
#   'learning'],
#  ['In',
#   'the',
#   'AUDI',
#   'Deep',
#   'Learning',
#   'Center',
#   'which',
#   'I',
#   'am',
#   'heading',
#   'we',
#   'apply',
#   'Deep',
#   'Learning',
#   'to',
#   'advance',
#   'autonomous',
#   'driving',
#   'using',
#   'LSTMs',
#   'for',
#   'sequence',
#   'prediction',
#   'and',
#   'for',
#   'attention'],
#  ['We',
#   'use',
#   'it',
#   'or',
#   'natural',
#   'language',
#   'processing',
#   'NLP',
#   'in',
#   'collaboration',
#   'with',
#   'company',
#   'like',
#   'Zalando',
#   'eg'],
#  ['to', 'analyze', 'fashion', 'blog'],
#  ['Using',
#   'Deep',
#   'Learning',
#   'we',
#   'won',
#   'the',
#   'NIH',
#   'Tox21',
#   'challenge',
#   'and',
#   'identified',
#   'unknown',
#   'side',
#   'effect',
#   'of',
#   'drug',
#   'candidate',
#   'based',
#   'on',
#   'data',
#   'from',
#   'bioassay',
#   'and',
#   'high',
#   'content',
#   'imaging'],
#  ['Sepp',
#   'Hochreiter',
#   'Head',
#   'of',
#   'Institute',
#   'of',
#   'Bioinformatics',
#   'JKU',
#   'Linz',
#   'Sepp',
#   'Hochreiter',
#   'is',
#   'heading',
#   'the',
#   'Institute',
#   'of',
#   'Bioinformatics',
#   'at',
#   'the',
#   'Johannes',
#   'Kepler',
#   'University',
#   'of',
#   'Linz',
#   'Austria',
#   'and',
#   'work',
#   'in',
#   'the',
#   'field',
#   'of',
#   'machine',
#   'learning',
#   'and',
#   'bioinformatics'],
#  ['He',
#   'is',
#   'a',
#   'pioneer',
#   'of',
#   'Deep',
#   'Learning',
#   'and',
#   'best',
#   'known',
#   'for',
#   'developing',
#   'the',
#   'long',
#   'short',
#   'term',
#   'memory',
#   'LSTM',
#   'in',
#   'his',
#   'diploma',
#   'thesis',
#   'in',
#   '1991',
#   'which',
#   'ha',
#   'been',
#   'published',
#   'later',
#   'in',
#   '1997'],
#  ['Since',
#   '2012',
#   'LSTM',
#   'is',
#   'used',
#   'in',
#   'Google',
#   '’',
#   's',
#   'Android',
#   'speech',
#   'recognizer',
#   'since',
#   '2015',
#   'in',
#   'Google',
#   '’',
#   's',
#   'Voice',
#   'transcription',
#   'since',
#   '2016',
#   'in',
#   'Google',
#   '’',
#   's',
#   'Allo',
#   'and',
#   'since',
#   '2016',
#   'in',
#   'Apple',
#   '’',
#   's',
#   'iOS',
#   '10',
#   'QuickType'],
#  ['Currently',
#   'Sepp',
#   'Hochreiter',
#   'is',
#   'advancing',
#   'the',
#   'theoretical',
#   'foundation',
#   'of',
#   'Deep',
#   'Learning',
#   'by',
#   'analyzing',
#   'gradient',
#   'flow',
#   'through',
#   'deep',
#   'network',
#   'and',
#   'selfnormalizing',
#   'neural',
#   'network'],
#  ['Furthermore',
#   'he',
#   'is',
#   'investigating',
#   'unsupervised',
#   'Deep',
#   'Learning',
#   'technique',
#   'like',
#   'generative',
#   'adversarial',
#   'network'],
#  ['His',
#   'current',
#   'research',
#   'project',
#   'include',
#   'Deep',
#   'Learning',
#   'for',
#   'drug',
#   'design',
#   'for',
#   'text',
#   'and',
#   'language',
#   'analysis',
#   'for',
#   'vision',
#   'and',
#   'in',
#   'particular',
#   'for',
#   'autonomous',
#   'driving'],
#  ['Deep',
#   'Learning',
#   'More',
#   'Than',
#   'Classification',
#   'Many',
#   'of',
#   'Deep',
#   'learning',
#   's',
#   'first',
#   'big',
#   'breakthrough',
#   'were',
#   'in',
#   'the',
#   'field',
#   'of',
#   'classification',
#   'for',
#   'example',
#   'recognizing',
#   'hand',
#   'written',
#   'digit',
#   'or',
#   'imagenet',
#   'image'],
#  ['While',
#   'such',
#   'result',
#   'were',
#   'impressive',
#   'they',
#   'are',
#   'only',
#   'a',
#   'drop',
#   'in',
#   'the',
#   'sea',
#   'of',
#   'possible',
#   'deep',
#   'learning',
#   'application',
#   'a',
#   'sea',
#   'who',
#   's',
#   'extent',
#   'we',
#   'are',
#   'only',
#   'just',
#   'now',
#   'beginning',
#   'to',
#   'discover'],
#  ['In',
#   'this',
#   'talk',
#   'I',
#   'll',
#   'demonstrate',
#   'a',
#   'sampling',
#   'of',
#   'and',
#   'exciting',
#   'deep',
#   'learning',
#   'application',
#   'we',
#   're',
#   'working',
#   'on',
#   'at',
#   'Zalando',
#   'in',
#   'cooperation',
#   'with',
#   'Prof',
#   'Dr',
#   'Sepp',
#   'Hochreiter',
#   's',
#   'team',
#   'at',
#   'JKU',
#   'Linz'],
#  ['These',
#   'include',
#   'image',
#   'generation',
#   'with',
#   'Generative',
#   'Adversarial',
#   'Networks',
#   'Semi',
#   'Supervised',
#   'Semantic',
#   'Segmentation',
#   'Warehouse',
#   'Optimization',
#   'and',
#   'Recommender',
#   'Systems'],
#  ['I',
#   'll',
#   'then',
#   'wrap',
#   'up',
#   'with',
#   'a',
#   'few',
#   'technical',
#   'tip',
#   'and',
#   'trick',
#   'on',
#   'how',
#   'you',
#   'too',
#   'can',
#   'start',
#   'learning',
#   'your',
#   'own',
#   'deep',
#   'neural',
#   'network'],
#  ['Calvin',
#   'Seward',
#   'Research',
#   'Scientist',
#   'Zalando',
#   'Calvin',
#   'Seward',
#   'is',
#   'a',
#   'Resarch',
#   'Scientist',
#   'in',
#   'Zalando',
#   's',
#   'Research',
#   'Lab',
#   'and',
#   'PhD',
#   'student',
#   'under',
#   'Prof',
#   'Dr',
#   'Sepp',
#   'Hochreiter',
#   'at',
#   'the',
#   'JKU',
#   'Linz',
#   'working',
#   'mainly',
#   'on',
#   'unsupervised',
#   'and',
#   'semisupervised',
#   'computer',
#   'vision',
#   'problem',
#   'including',
#   'classification',
#   'localization',
#   'semantic',
#   'segmentation',
#   'and',
#   'image',
#   'generation'],
#  ['The',
#   'main',
#   'line',
#   'of',
#   'attack',
#   'for',
#   'these',
#   'problem',
#   'is',
#   'deep',
#   'neural',
#   'network',
#   'written',
#   'in',
#   'the',
#   'Tensorflow',
#   'framework',
#   'and',
#   'trained',
#   'on',
#   'GPU',
#   'cluster'],
#  ['At',
#   'the',
#   'same',
#   'time',
#   'he',
#   'is',
#   'involved',
#   'in',
#   'applying',
#   'lesson',
#   'from',
#   'GPUdriven',
#   'HPC',
#   'computing',
#   'and',
#   'cutting',
#   'edge',
#   'Machine',
#   'Learning',
#   'to',
#   'other',
#   'field',
#   'of',
#   'the',
#   'Zalando',
#   'universe'],
#  ['Past',
#   'project',
#   'have',
#   'included',
#   'sizing',
#   'solution',
#   'for',
#   'online',
#   'retail',
#   'warehouse',
#   'management',
#   'and',
#   'recommendation',
#   'system'],
#  ['Seizing',
#   'the',
#   'Machine',
#   'Learning',
#   'Opportunity',
#   'Gartner',
#   'predicts',
#   '2017',
#   'to',
#   'be',
#   'the',
#   'year',
#   'when',
#   'Machine',
#   'Learning',
#   'reach',
#   'it',
#   'peak',
#   'in',
#   'term',
#   'of',
#   'inflated',
#   'expectation'],
#  ['This',
#   'is',
#   'the',
#   'right',
#   'time',
#   'to',
#   'not',
#   'only',
#   'talk',
#   'about',
#   'the',
#   'sea',
#   'of',
#   'opportunity',
#   'but',
#   'also',
#   'provide',
#   'a',
#   'nononsense',
#   'view',
#   'of',
#   'the',
#   'practical',
#   'obstacle',
#   'which',
#   'organization',
#   'will',
#   'encounter',
#   'on',
#   'their',
#   'path',
#   'to',
#   'seizing',
#   'them'],
#  ['In',
#   'this',
#   'talk',
#   'I',
#   'll',
#   'cover',
#   'these',
#   'topic',
#   'from',
#   'a',
#   'managerial',
#   'perspective',
#   'Machine',
#   'Learning',
#   'use',
#   'case',
#   'from',
#   'the',
#   'industry',
#   'Factors',
#   'of',
#   'success',
#   'and',
#   'nonsuccess',
#   'Ideation',
#   'process',
#   'for',
#   'data',
#   'product',
#   'Efficient',
#   'organizational',
#   'setup',
#   'Recruiting',
#   'retaining',
#   'of',
#   'data',
#   'scientist',
#   'Ulla',
#   'KruhseLehtonen',
#   'CEO',
#   'DAIN',
#   'Studios',
#   'Ulla',
#   'is',
#   'the',
#   'CEO',
#   'of',
#   'DAIN',
#   'Studios',
#   'a',
#   'rapidly',
#   'growing',
#   'Data',
#   'and',
#   'Artificial',
#   'Intelligence',
#   'consulting',
#   'product',
#   'startup',
#   'operating',
#   'in',
#   'Finland',
#   'and',
#   'DACH'],
#  ['She',
#   'started',
#   'her',
#   'career',
#   'a',
#   'a',
#   'microeconomist',
#   'moved',
#   'into',
#   'management',
#   'and',
#   'economics',
#   'consulting',
#   'at',
#   'the',
#   'turn',
#   'of',
#   'the',
#   'century',
#   'focusing',
#   'on',
#   'a',
#   'variety',
#   'of',
#   'topic',
#   'such',
#   'a',
#   'supply',
#   'chain',
#   'optimization',
#   'telco',
#   'billing',
#   'system',
#   'analytical',
#   'CRM',
#   'and',
#   'econometric',
#   'evaluation',
#   'of',
#   'international',
#   'organization'],
#  ['In',
#   '2008',
#   'she',
#   'moved',
#   'to',
#   'the',
#   'client',
#   'side',
#   'and',
#   'ha',
#   'launched',
#   'developed',
#   'and',
#   'led',
#   'Consumer',
#   'Analytics',
#   'function',
#   'in',
#   'two',
#   'large',
#   'company'],
#  ['At',
#   'Nokia',
#   'she',
#   'established',
#   'the',
#   'global',
#   'Consumer',
#   'Analytics',
#   'Department',
#   'with',
#   'over',
#   '30',
#   'data',
#   'scientist',
#   'providing',
#   'support',
#   'in',
#   'sale',
#   'and',
#   'marketing',
#   'supply',
#   'chain',
#   'and',
#   'product',
#   'analytics',
#   'to',
#   'Nokia',
#   '’',
#   's',
#   '70',
#   'local',
#   'operation'],
#  ['At',
#   'Sanoma',
#   'a',
#   'Vice',
#   'President',
#   'for',
#   'Consumer',
#   'Analytics',
#   'and',
#   'Insights',
#   'Ulla',
#   'established',
#   'and',
#   'led',
#   'the',
#   'Analytics',
#   'Center',
#   'of',
#   'Excellence',
#   'a',
#   '45person',
#   'unit',
#   'operating',
#   'in',
#   'Finland',
#   'and',
#   'the',
#   'Netherlands',
#   'serving',
#   'Sanoma',
#   '’',
#   's',
#   'medium',
#   'and',
#   'learning',
#   'business'],
#  ['In',
#   '2013',
#   'Ulla',
#   'wa',
#   'recognized',
#   'a',
#   'the',
#   'Information',
#   'Leader',
#   'of',
#   'the',
#   'Year',
#   'in',
#   'Finland'],
#  ['She',
#   'hold',
#   'a',
#   'PhD',
#   'in',
#   'Economics',
#   'from',
#   'the',
#   'Helsinki',
#   'School',
#   'of',
#   'Economics',
#   'Aalto',
#   'University'],
#  ['Machine',
#   'Learning',
#   'with',
#   'Google',
#   'Cloud',
#   'Artificial',
#   'intelligence',
#   'and',
#   'machine',
#   'learning',
#   'ha',
#   'great',
#   'potential',
#   'to',
#   'improve',
#   'our',
#   'life'],
#  ['Google',
#   'ha',
#   'made',
#   'machine',
#   'learning',
#   'a',
#   'central',
#   'part',
#   'of',
#   'how',
#   'they',
#   'design',
#   'service',
#   'and',
#   'Google',
#   'Cloud',
#   'ha',
#   'developed',
#   'several',
#   'way',
#   'for',
#   'both',
#   'data',
#   'scientist',
#   'and',
#   'software',
#   'developer',
#   'to',
#   'realize',
#   'that',
#   'potential'],
#  ['In',
#   'this',
#   'session',
#   'we',
#   'will',
#   'walk',
#   'through',
#   'example',
#   'of',
#   'how',
#   'Google',
#   'us',
#   'machine',
#   'learning',
#   'internally',
#   'and',
#   'then',
#   'introduce',
#   'different',
#   'way',
#   'people',
#   'are',
#   'working',
#   'with',
#   'Google',
#   'and',
#   'Google',
#   'Cloud',
#   'including',
#   'TensorFlow',
#   'an',
#   'opensource',
#   'machine',
#   'learning',
#   'platform',
#   'that',
#   'is',
#   'fast',
#   'flexible',
#   'and',
#   'productionready',
#   'and',
#   'scale',
#   'from',
#   'research',
#   'to',
#   'production'],
#  ['Google',
#   'Cloud',
#   'Machine',
#   'Learning',
#   'Engine',
#   'a',
#   'managed',
#   'service',
#   'that',
#   'enables',
#   'you',
#   'to',
#   'build',
#   'machine',
#   'learning',
#   'model',
#   'that',
#   'work',
#   'on',
#   'any',
#   'type',
#   'of',
#   'data',
#   'of',
#   'any',
#   'size'],
#  ['APIs',
#   'pretrained',
#   'model',
#   'available',
#   'via',
#   'application',
#   'programming',
#   'interface',
#   'APIs',
#   'that',
#   'allow',
#   'software',
#   'developer',
#   'to',
#   'realize',
#   'ML',
#   'benefit',
#   'in',
#   'domain',
#   'such',
#   'a',
#   'image',
#   'analysis',
#   'video',
#   'analysis',
#   'speech',
#   'recognition',
#   'text',
#   'analysis',
#   'and',
#   'dynamic',
#   'translation'],
#  ['Dave',
#   'Elliott',
#   'Global',
#   'Product',
#   'Lead',
#   'Google',
#   'Dave',
#   'Elliott',
#   'is',
#   'a',
#   'technology',
#   'evangelist',
#   'and',
#   'an',
#   'Architect',
#   'Advocate',
#   'for',
#   'cloud',
#   'platform',
#   'at',
#   'Google'],
#  ['In',
#   'this',
#   'role',
#   'he',
#   'engages',
#   'community',
#   'to',
#   'inspire',
#   'them',
#   'to',
#   'try',
#   'new',
#   'product',
#   'and',
#   'technology',
#   'embrace',
#   'new',
#   'idea',
#   'and',
#   'he',
#   'is',
#   'the',
#   'voice',
#   'of',
#   'those',
#   'community',
#   'to',
#   'product',
#   'and',
#   'engineering',
#   'team'],
#  ['Prior',
#   'to',
#   'Google',
#   'Elliott',
#   'wa',
#   'a',
#   'Chief',
#   'Cloud',
#   'Evangelist',
#   'at',
#   'Symantec',
#   'where',
#   'he',
#   'advocated',
#   'for',
#   'new',
#   'architecture',
#   'in',
#   'data',
#   'and',
#   'storage'],
#  ['Mr',
#   'Elliott',
#   'wa',
#   'an',
#   'early',
#   'advocate',
#   'of',
#   'cloud',
#   'computing',
#   'while',
#   'at',
#   'Sun',
#   'Microsystems',
#   'in',
#   'the',
#   '1990s',
#   'and',
#   'ha',
#   'spent',
#   'his',
#   'career',
#   'helping',
#   'company',
#   'understand',
#   'and',
#   'embrace',
#   'emerging',
#   'technology'],
#  ['Mr',
#   'Elliott',
#   'hold',
#   'an',
#   'MBA',
#   'from',
#   'the',
#   'University',
#   'of',
#   'California',
#   'at',
#   'Berkeley',
#   'and',
#   'an',
#   'BA',
#   'in',
#   'Quantitative',
#   'Economics',
#   'Decision',
#   'Sciences',
#   'from',
#   'the',
#   'University',
#   'of',
#   'California',
#   'San',
#   'Diego'],
#  ['Neural',
#   'Networks',
#   'for',
#   'Natural',
#   'Language',
#   'Processing',
#   'Artificial',
#   'neural',
#   'network',
#   'are',
#   'currently',
#   'very',
#   'successful',
#   'in',
#   'various',
#   'machine',
#   'learning',
#   'task',
#   'that',
#   'involve',
#   'natural',
#   'language'],
#  ['In',
#   'this',
#   'talk',
#   'I',
#   'will',
#   'describe',
#   'recurrent',
#   'neural',
#   'network',
#   'language',
#   'model',
#   'a',
#   'well',
#   'a',
#   'their',
#   'most',
#   'frequent',
#   'application',
#   'to',
#   'speech',
#   'recognition',
#   'and',
#   'machine',
#   'translation'],
#  ['I',
#   'will',
#   'also',
#   'talk',
#   'about',
#   'distributed',
#   'word',
#   'representation',
#   'their',
#   'interesting',
#   'property',
#   'and',
#   'efficient',
#   'way',
#   'how',
#   'to',
#   'compute',
#   'them',
#   'and',
#   'use',
#   'in',
#   'task',
#   'such',
#   'a',
#   'text',
#   'classification'],
#  ['Finally',
#   'I',
#   'will',
#   'describe',
#   'our',
#   'latest',
#   'effort',
#   'to',
#   'create',
#   'a',
#   'novel',
#   'dataset',
#   'that',
#   'could',
#   'be',
#   'used',
#   'to',
#   'develop',
#   'machine',
#   'that',
#   'can',
#   'truly',
#   'communicate',
#   'with',
#   'human',
#   'user',
#   'in',
#   'natural',
#   'language'],
#  ['Tomáš',
#   'Mikolov',
#   'AI',
#   'Research',
#   'Scientist',
#   'Facebook',
#   'Tomáš',
#   'Mikolov',
#   'is',
#   'a',
#   'research',
#   'scientist',
#   'at',
#   'Facebook',
#   'AI',
#   'Research',
#   'group',
#   'since',
#   '2014'],
#  ['Previously',
#   'he',
#   'ha',
#   'been',
#   'member',
#   'of',
#   'the',
#   'Google',
#   'Brain',
#   'team',
#   'where',
#   'he',
#   'developed',
#   'and',
#   'implemented',
#   'efficient',
#   'algorithm',
#   'for',
#   'computing',
#   'distributed',
#   'representation',
#   'of',
#   'word',
#   'the',
#   'word2vec',
#   'project'],
#  ['He',
#   'obtained',
#   'his',
#   'PhD',
#   'from',
#   'the',
#   'Brno',
#   'University',
#   'of',
#   'Technology',
#   'Czech',
#   'Republic',
#   'in',
#   '2012',
#   'for',
#   'his',
#   'work',
#   'on',
#   'recurrent',
#   'neural',
#   'networkbased',
#   'language',
#   'model',
#   'RNNLM'],
#  ['His',
#   'long',
#   'term',
#   'research',
#   'goal',
#   'is',
#   'to',
#   'develop',
#   'intelligent',
#   'machine',
#   'that',
#   'people',
#   'can',
#   'communicate',
#   'with',
#   'and',
#   'use',
#   'to',
#   'accomplish',
#   'complex',
#   'task'],
#  ['function',
#   'i',
#   's',
#   'o',
#   'g',
#   'r',
#   'a',
#   'm',
#   'i',
#   'GoogleAnalyticsObject',
#   'r',
#   'i',
#   'r',
#   'i',
#   'r',
#   'function',
#   'i',
#   'r',
#   'qi',
#   'r',
#   'q',
#   'push',
#   'argument',
#   'i',
#   'r',
#   'l1new',
#   'Date',
#   'ascreateElement',
#   'o',
#   'msgetElementsByTagName',
#   'o',
#   '0',
#   'aasync1',
#   'asrcg',
#   'mparentNodeinsertBefore',
#   'a',
#   'm',
#   'window',
#   'document',
#   'script',
#   'wwwgoogleanalyticscomanalyticsjs',
#   'ga',
#   'ga',
#   'create',
#   'UA913981971',
#   'mostlyaisummit',
#   'ga',
#   'send',
#   'pageview',
#   'windowjQuery',
#   'documentwrite',
#   'script',
#   'src',
#   'summitjsjquery211minjs',
#   'script',
#   'if',
#   'typeof',
#   'fnmodal',
#   'undefined',
#   'documentwrite',
#   'script',
#   'src',
#   'summitjsbootstrapminjs',
#   'script',
#   'WavesdisplayEffect',
#   'var',
#   'twitterFeedUrl',
#   'document',
#   'ready',
#   'function',
#   'function',
#   'if',
#   'window',
#   'width',
#   '767',
#   'typeouttext',
#   'typed',
#   'string',
#   'typeSpeed',
#   '150',
#   'backDelay',
#   '900',
#   'loop',
#   'true',
#   'var',
#   'rockstarSpeakers',
#   'name',
#   'Sepp',
#   'Hochreiter',
#   'company',
#   'JKU',
#   'Linz',
#   'Head',
#   'of',
#   'Institute',
#   'of',
#   'Bioinformatics',
#   'image',
#   'summitimgpeopleSeppHochreiterjpg',
#   'name',
#   'Calvin',
#   'Seward',
#   'company',
#   'Zalando',
#   'Research',
#   'Scientist',
#   'image',
#   'summitimgpeopleCalvinSewardjpg',
#   'name',
#   'Ulla',
#   'KruhseLehtonen',
#   'company',
#   'DAIN',
#   'Studios',
#   'CEO',
#   'image',
#   'summitimgpeopleUllaKruhseLehtonenjpg',
#   'name',
#   'Dave',
#   'Elliott',
#   'company',
#   'Google',
#   'Global',
#   'Product',
#   'Lead',
#   'image',
#   'summitimgpeopleDaveElliotjpg',
#   'name',
#   'Tomáš',
#   'Mikolov',
#   'company',
#   'Facebook',
#   'AI',
#   'Research',
#   'Scientist',
#   'image',
#   'summitimgpeopleThomasMikolovjpg',
#   'rockstarSpeakerssort',
#   'function',
#   'return',
#   '05',
#   'Mathrandom',
#   'if',
#   'rockstarSpeakerslength',
#   '0',
#   'var',
#   'animationDelay',
#   '1500',
#   'count',
#   'Mathmin',
#   '5',
#   'rockstarSpeakerslength',
#   'colWidth',
#   '12count',
#   'for',
#   'i0',
#   'i',
#   'count',
#   'i',
#   'var',
#   'clearfix',
#   'div',
#   'class',
#   'clearfix',
#   'visiblexs',
#   'div',
#   'if',
#   'i',
#   '2',
#   '0',
#   'clearfix',
#   'rockstarspeakertitle',
#   'after',
#   'div',
#   'class',
#   'colmd',
#   'colWidth',
#   'colxs6',
#   'rockstarspeakersitem',
#   'animated',
#   'hiding',
#   'dataanimation',
#   'fadeInUp',
#   'datadelay',
#   'animationDelay',
#   'div',
#   'class',
#   'rockstarspeaker',
#   'div',
#   'class',
#   'flowimg',
#   'imgcircle',
#   'rockstarspeakerimg',
#   'style',
#   'backgroundimage',
#   'url',
#   'rockstarSpeakers',
#   'i',
#   'image',
#   'div',
#   'div',
#   'class',
#   'name',
#   'rockstarSpeakers',
#   'i',
#   'name',
#   'div',
#   'div',
#   'class',
#   'sub',
#   'rockstarSpeakers',
#   'i',
#   'company',
#   'div',
#   'div',
#   'div',
#   'clearfix',
#   'animationDelay',
#   '500',
#   'context',
#   'http',
#   'schemaorg',
#   'type',
#   'Event',
#   'name',
#   'AI',
#   'Summit',
#   'Vienna',
#   'description',
#   'AI',
#   'Summit',
#   'Vienna',
#   'image',
#   'http',
#   'mostlyaigithubiosummitimgseosharinggooglepluspng',
#   'url',
#   'http',
#   'mostlyaigithubio',
#   'startDate',
#   '20170904T0900',
#   'doorTime',
#   '0900',
#   'endDate',
#   '20170904T2100',
#   'location',
#   'type',
#   'Place',
#   'name',
#   'Learning',
#   'Center',
#   'WU',
#   'Campus',
#   'sameAs',
#   'http',
#   'googlmapsM7rdWybAQM62',
#   'address',
#   'type',
#   'PostalAddress',
#   'streetAddress',
#   'Welthandelsplatz',
#   '1',
#   '1',
#   '1020',
#   'Wien',
#   'Austria',
#   'addressLocality',
#   'Vienna',
#   'addressRegion',
#   'postalCode',
#   '1020',
#   'addressCountry',
#   'Austria',
#   'geo',
#   'type',
#   'GeoCoordinates',
#   'latitude',
#   '482141753',
#   'longitude',
#   '164068405',
#   'Not',
#   'supported',
#   'yet',
#   'organizer',
#   'type',
#   'Organization',
#   'name',
#   'Mostly',
#   'AI',
#   'the',
#   'Vienna',
#   'Deep',
#   'Learning',
#   'Meetup',
#   'alternateName',
#   'Mostly',
#   'AI',
#   'the',
#   'Vienna',
#   'Deep',
#   'Learning',
#   'Meetup',
#   'description',
#   'logo',
#   'http',
#   'mostlyaigithubiosummitimgseoorganizerlogopng',
#   'email',
#   'summit',
#   'mostlyai',
#   'sameAs',
#   'http',
#   'mostlyai',
#   'subEvent',
#   'type',
#   'Event',
#   'name',
#   'description',
#   'image',
#   'http',
#   'mostlyaigithubiosummitimgseosharinggooglepluspng',
#   'url',
#   'http',
#   'mostlyaigithubiosummithackathon',
#   'startDate',
#   'doorTime',
#   'endDate',
#   'location',
#   'type',
#   'Place',
#   'name',
#   'sameAs',
#   'address',
#   'type',
#   'PostalAddress',
#   'streetAddress',
#   'addressLocality',
#   'addressRegion',
#   'postalCode',
#   'addressCountry',
#   'geo',
#   'type',
#   'GeoCoordinates',
#   'latitude',
#   'longitude',
#   'offer',
#   'type',
#   'Offer',
#   'name',
#   'Attendance',
#   'url',
#   'http',
#   'wwweventbritecomeaisummitviennatickets33993018032',
#   'price',
#   '8',
#   'priceCurrency',
#   'EUR',
#   'validFrom',
#   'validThrough',
#   'type',
#   'Offer',
#   'name',
#   'Startup',
#   'Table',
#   'url',
#   'http',
#   'mostlyaisummitassetsAISummitViennaStartupTablepdf',
#   'price',
#   '250',
#   'priceCurrency',
#   'EUR',
#   'validFrom',
#   'validThrough',
#   'performer',
#   'type',
#   'Person',
#   'name',
#   'Sepp',
#   'Hochreiter',
#   'image',
#   'http',
#   'mostlyaigithubiosummitimgpeopleSeppHochreiterjpg',
#   'jobTitle',
#   'Head',
#   'of',
#   'Institute',
#   'of',
#   'Bioinformatics',
#   'worksFor',
#   'type',
#   'Organization',
#   'name',
#   'JKU',
#   'Linz',
#   'sameAs',
#   'http',
#   'wwwbioinfjkuatpeoplehochreiter',
#   'type',
#   'Person',
#   'name',
#   'Calvin',
#   'Seward',
#   'image',
#   'http',
#   'mostlyaigithubiosummitimgpeopleCalvinSewardjpg',
#   'jobTitle',
#   'Research',
#   'Scientist',
#   'worksFor',
#   'type',
#   'Organization',
#   'name',
#   'Zalando',
#   'sameAs',
#   'http',
#   'wwwlinkedincomincalvinseward',
#   'type',
#   'Person',
#   'name',
#   'Ulla',
#   'KruhseLehtonen',
#   'image',
#   'http',
#   'mostlyaigithubiosummitimgpeopleUllaKruhseLehtonenjpg',
#   'jobTitle',
#   'CEO',
#   'worksFor',
#   'type',
#   'Organization',
#   'name',
#   'DAIN',
#   'Studios',
#   'sameAs',
#   'http',
#   'wwwdainstudioscom',
#   'type',
#   'Person',
#   'name',
#   'Dave',
#   'Elliott',
#   'image',
#   'http',
#   'mostlyaigithubiosummitimgpeopleDaveElliotjpg',
#   'jobTitle',
#   'Global',
#   'Product',
#   'Lead',
#   'worksFor',
#   'type',
#   'Organization',
#   'name',
#   'Google',
#   'sameAs',
#   'http',
#   'wwwlinkedincomindavidlelliott',
#   'type',
#   'Person',
#   'name',
#   'Tomáš',
#   'Mikolov',
#   'image',
#   'http',
#   'mostlyaigithubiosummitimgpeopleThomasMikolovjpg',
#   'jobTitle',
#   'AI',
#   'Research',
#   'Scientist',
#   'worksFor',
#   'type',
#   'Organization',
#   'name',
#   'Facebook',
#   'sameAs',
#   'http',
#   'researchfbcompeoplemikolovtomas',
#   'eventStatus',
#   'EventScheduled',
#   'typicalAgeRange',
#   '16']]
